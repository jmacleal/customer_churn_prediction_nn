# %% [markdown]
# # Customer Churn Prediction
# Machine Learning Project - Decison Tree Classification
#
# Authors:
# * José Marcos Leal Barbosa Filho
# * Lucas Ismael Campos Medeiros
#
# Institution: Universidade Federal do Rio Grande do Norte - Brazil.

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# It is a **customer churn** modeling dataset containing 10.000 rows (each representing an unique customer) with 14 columns: 13 general features and one target feature (**Exited**). The data is composed of both numerical and categorical features:
#
# **Numeric Features:**
#
#     RowNumber: The sequence number of the rows.
#     CustomerId: A unique ID of the customer.
#     CreditScore: The credit score of the customer,
#     Age: The age of the customer,
#     Tenure: The number of months the client has been with the firm.
#     Balance: Balance remaining in the customer account,
#     NumOfProducts: The number of products purchased by the customer.
#     EstimatedSalary: The estimated salary of the customer.
#
# **Categorical Features:**
#
#     Surname: The surname of the customer.
#     Geography: The country of the customer.
#     Gender: M/F
#     HasCrCard: Whether the customer has a credit card or not.
#     IsActiveMember: Whether the customer is active or not.
#
# **The target column:**
#
#     Exited — Whether the customer churned or not.
#
# The dataset can be seen and downloaded [here](https://www.kaggle.com/datasets/aakash50897/churn-modellingcsv?resource=download).

# %% [markdown]
# ## Load Libraries

# %%
# %%capture
# !pip install wandb
#!pip install wandb==0.10.17
# !pip install pytest pytest-sugar
# !pip install pandas-profiling==3.1.0

# %%
import wandb
import logging
import tempfile
import os
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas_profiling import ProfileReport
from sklearn.model_selection import train_test_split
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.impute import SimpleImputer
from sklearn.metrics import fbeta_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

import tensorflow as tf
from tensorflow import keras
from wandb.keras import WandbCallback
from keras.callbacks import EarlyStopping
import h5py
import time
import datetime
import pytz
import IPython

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ## Login to wandb

# %%
# !wandb login --relogin
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## 1 - Extract, Transform and Load (ETL)

# %% [markdown]
# ### 1.1 Fetch Data

# %%
# columns used
columns = ['RowNumber', 'CustomerId', 'Surname', 'CreditScore',
           'Geography', 'Gender', 'Age', 'Tenure', 
           'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
           'EstimatedSalary', 'Exited']
# importing the dataset
churndf = pd.read_csv("https://github.com/x4nth055/pythoncode-tutorials/raw/master/machine-learning/customer-churn-detection/Churn_Modelling.csv",
                      header=None,
                      names=columns)
churndf.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Geography  Gender  Age  \
# 0  RowNumber  CustomerId   Surname  CreditScore  Geography  Gender  Age
# 1          1    15634602  Hargrave          619     France  Female   42
# 2          2    15647311      Hill          608      Spain  Female   41
# 3          3    15619304      Onio          502     France  Female   42
# 4          4    15701354      Boni          699     France  Female   39
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0  Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember
# 1       2         0              1          1               1
# 2       1  83807.86              1          0               1
# 3       8  159660.8              3          1               0
# 4       1         0              2          0               0
#
#    EstimatedSalary  Exited
# 0  EstimatedSalary  Exited
# 1        101348.88       1
# 2        112542.58       0
# 3        113931.57       1
# 4         93826.63       0

# %% [markdown]
# * It was chosen to remove the following columns:
#
#   * **RowNumber:** Indicates only the sequence number of the lines;
#   * **CustomerId:** High cardinality column with 10,000 unique IDs;
#   * **Surname:** Column with high cardinality, showing the last names of each consumer.

# %%
# removing unecessary columns and reseting indexes
churndf = churndf.drop([0,])
churndf.drop(columns=['RowNumber', 'CustomerId', 'Surname'], inplace=True)
churndf.reset_index(drop=True,inplace=True)
churndf.head()
# Out:
#   CreditScore Geography  Gender Age Tenure    Balance NumOfProducts HasCrCard  \
# 0         619    France  Female  42      2          0             1         1
# 1         608     Spain  Female  41      1   83807.86             1         0
# 2         502    France  Female  42      8   159660.8             3         1
# 3         699    France  Female  39      1          0             2         0
# 4         850     Spain  Female  43      2  125510.82             1         1
#
#   IsActiveMember EstimatedSalary Exited
# 0              1       101348.88      1
# 1              1       112542.58      0
# 2              0       113931.57      1
# 3              0        93826.63      0
# 4              1         79084.1      0

# %%
# saving to csv
churndf.to_csv("raw_data.csv", index=False)

# %%
# Saving artifact to wandb
# !wandb artifact put \
       --name churn_prediction_project_nn/raw_data.csv \
       --type raw_data \
       --description "Customer Churn NN" raw_data.csv
# Out:
# wandb: Uploading file raw_data.csv to: "eec1509/churn_prediction_project_nn/raw_data.csv:latest" (raw_data)
# wandb: Currently logged in as: macleal (eec1509). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.21
# wandb: Run data is saved locally in /content/wandb/run-20220714_121421-9syst0ri
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run celestial-sun-8
# wandb: ⭐️ View project at https://wandb.ai/eec1509/churn_prediction_project_nn
# wandb: 🚀 View run at https://wandb.ai/eec1509/churn_prediction_project_nn/runs/9syst0ri
# Artifact uploaded, use this artifact in a run by adding:
#
#     artifact = run.use_artifact("eec1509/churn_prediction_project_nn/raw_data.csv:v0")
#
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Synced celestial-sun-8: https://wandb.ai/eec1509/churn_prediction_project_nn/runs/9syst0ri
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220714_121421-9syst0ri/logs

# %% [markdown]
# ----------------

# %% [markdown]
# ### 1.2 Exploratory Data Analysis (EDA)

# %%
# save_code tracking all changes of the notebook and sync with Wandb
run = wandb.init(project="churn_prediction_project_nn", save_code=True)
# Out:
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220714_121429-1l5x2bzr</code>
# Syncing run <strong><a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1l5x2bzr" target="_blank">twilight-snow-9</a></strong> to <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# download the latest version of artifact raw_data.csv
artifact = run.use_artifact("churn_prediction_project_nn/raw_data.csv:latest")

# create a dataframe from the artifact
df = pd.read_csv(artifact.file())

# %% [markdown]
# #### 1.2.1 Pandas Profiling

# %%
ProfileReport(df, title= "Pandas Profiling Report", explorative=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.507 MB of 0.507 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">twilight-snow-9</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1l5x2bzr" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1l5x2bzr</a><br/>Synced 4 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220714_121429-1l5x2bzr/logs</code>

# %% [markdown]
# --------------------------

# %% [markdown]
# ### 1.3 Preprocessing

# %%
input_artifact="churn_prediction_project_nn/raw_data.csv:latest"
artifact_name="preprocessed_data.csv"
artifact_type="clean_data"
artifact_description="Data after preprocessing"

# %%
# create a new job_type
run = wandb.init(project="churn_prediction_project_nn", job_type="process_data")
# Out:
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220714_121507-3axkmpty</code>
# Syncing run <strong><a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3axkmpty" target="_blank">fresh-energy-10</a></strong> to <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# download the latest version of artifact raw_data.csv
artifact=run.use_artifact(input_artifact)

# create a dataframe from the artifact
df = pd.read_csv(artifact.file())

# %%
# delete duplicated rows
df.drop_duplicates(inplace=True)

# generate a "clean data file"
df.to_csv(artifact_name, index=False)

# %%
# Create a new artifact and configure with the necessary arguments
artifact = wandb.Artifact(name=artifact_name,
                         type=artifact_type,
                         description=artifact_description)
artifact.add_file(artifact_name)
# Out:
# <ManifestEntry digest: 2VNPzyBON65Yp9cxPORlnA==>

# %%
run.log_artifact(artifact)

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">fresh-energy-10</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3axkmpty" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3axkmpty</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220714_121507-3axkmpty/logs</code>

# %% [markdown]
# ----------------------------

# %% [markdown]
# ## 2 - Data Check

# %%
# %%file test_data.py
import pytest
import wandb
import pandas as pd

# This is global so all tests are collected under the same run
run = wandb.init(project="churn_prediction_project_nn", job_type="data_checks")

@pytest.fixture(scope="session")
def data():

    local_path = run.use_artifact("churn_prediction_project_nn/preprocessed_data.csv:latest").file()
    df = pd.read_csv(local_path)

    return df

def test_data_length(data):
    """
    We test that we have enough data to continue
    """
    assert len(data) > 1000


def test_number_of_columns(data):
    """
    We test that we have enough data to continue
    """
    assert data.shape[1] == 11

def test_column_presence_and_type(data):

    required_columns = {
        #"CustomerId": pd.api.types.is_int64_dtype,
        #"Surname": pd.api.types.is_object_dtype,
        "CreditScore": pd.api.types.is_int64_dtype,
        "Geography": pd.api.types.is_object_dtype,
        "Gender": pd.api.types.is_object_dtype,
        "Age": pd.api.types.is_int64_dtype,
        "Tenure": pd.api.types.is_int64_dtype,
        "Balance": pd.api.types.is_float_dtype,
        "NumOfProducts": pd.api.types.is_int64_dtype,
        "HasCrCard": pd.api.types.is_int64_dtype,
        "IsActiveMember": pd.api.types.is_int64_dtype,
        "EstimatedSalary": pd.api.types.is_float_dtype,  
        "Exited": pd.api.types.is_int64_dtype
    }

    # Check column presence
    assert set(data.columns.values).issuperset(set(required_columns.keys()))

    for col_name, format_verification_funct in required_columns.items():

        assert format_verification_funct(data[col_name]), f"Column {col_name} failed test {format_verification_funct}"


def test_class_names(data):

    # Check that only the known classes are present
    known_classes = [
        0,
        1
    ]

    assert data["Exited"].isin(known_classes).all()


def test_column_ranges(data):

    ranges = {
        "CreditScore": (0, 1000),
        "Age": (0,100),
        "Tenure": (0,10),
        "Balance": (0, 1.484705e+06),
        "NumOfProducts": (1,4),
        "HasCrCard": (0,1),
        "IsActiveMember": (0,1),
        "EstimatedSalary": (0, 1.484705e+06),
        "Exited": (0, 1)
    }

    for col_name, (minimum, maximum) in ranges.items():

        assert data[col_name].dropna().between(minimum, maximum).all(), (
            f"Column {col_name} failed the test. Should be between {minimum} and {maximum}, "
            f"instead min={data[col_name].min()} and max={data[col_name].max()}"
        )
# Out:
# Overwriting test_data.py

# %%
# !pytest . -vv
# Out:
# Test session starts (platform: linux, Python 3.7.13, pytest 3.6.4, pytest-sugar 0.9.5)
# cachedir: .pytest_cache
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1, sugar-0.9.5
#
#  test_data.py::test_data_length ✓                                 20% ██
#  test_data.py::test_number_of_columns ✓                           40% ████
#  test_data.py::test_column_presence_and_type ✓                    60% ██████
#  test_data.py::test_class_names ✓                                 80% ████████
#  test_data.py::test_column_ranges ✓                              100% ██████████
#
# Results (3.51s):
#        5 passed

# %%
run.finish()

# %% [markdown]
# ----------------------------------------

# %% [markdown]
# ## 3 - Data Segregation

# %%
# global variables

# ratio - 70% train / 30% test
test_size = 0.30

# seed used to reproduce purposes
seed = 42

# reference (column) to stratify the data
stratify = "Exited"

# name of the input artifact
artifact_input_name = "churn_prediction_project_nn/preprocessed_data.csv:latest"

# type of the artifact
artifact_type = "segregated_data"

# %%
# configure logging 
logging.basicConfig(level=logging.INFO,
                   format="%(asctime)s %(message)s",
                   datefmt='%d-%m-%Y %H:%M:%S')

# reference for a logging object
logger = logging.getLogger()

# init wandb project
run = wandb.init(project="churn_prediction_project_nn", job_type="split_data")

logger.info("Downloading and reading artifact")
artifact=run.use_artifact(artifact_input_name)
artifact_path=artifact.file()
df = pd.read_csv(artifact_path)

# Split in train/test
logger.info("Splitting data into train and test")
splits = {}

splits["train"], splits["test"] = train_test_split(df,
                                                  test_size=test_size,
                                                  random_state=seed,
                                                  stratify=df[stratify])
# Out:
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220714_121544-ior3m9n9</code>
# Syncing run <strong><a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/ior3m9n9" target="_blank">generous-eon-12</a></strong> to <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 14-07-2022 12:15:49 Downloading and reading artifact
# 14-07-2022 12:15:50 Splitting data into train and test

# %%
# Save artifacts
with tempfile.TemporaryDirectory() as tmp_dir:
    
    for split, df in splits.items():
        
        # Make the artifact name from the name of the split plus the provided root
        artifact_name = f"{split}.csv"
        
        # Get the path on disk within the temp directory
        temp_path = os.path.join(tmp_dir,artifact_name)
        
        logger.info(f"Uploading the {split} dataset to {artifact_name}")
        
        # Save then upload to W&B
        df.to_csv(temp_path,index=False)
        
        artifact = wandb.Artifact(name=artifact_name,
                                 type=artifact_type,
                                 description=f"{split} split of dataset {artifact_input_name}")
        artifact.add_file(temp_path)
        
        logger.info("Logging artifact")
        run.log_artifact(artifact)
        
        artifact.wait()
# Out:
# 14-07-2022 12:15:50 Uploading the train dataset to train.csv
# 14-07-2022 12:15:50 Logging artifact
# 14-07-2022 12:15:53 Uploading the test dataset to test.csv
# 14-07-2022 12:15:53 Logging artifact

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.448 MB of 0.448 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">generous-eon-12</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/ior3m9n9" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/ior3m9n9</a><br/>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220714_121544-ior3m9n9/logs</code>

# %% [markdown]
# ------------------------

# %% [markdown]
# ## 4 - Trainning

# %% [markdown]
# ### 4.1 Holdout Configuration

# %%
# global variables

# ratio used to split train and validation data
val_size = 0.30

# seed used to reproduce purposes
seed = 42

# reference (column) to stratify the data
stratify = "Exited"

# name of the input artifact
artifact_input_name = "churn_prediction_project_nn/train.csv:latest"

#entity
entity_name = "eec1509"

# project name
project_name = "churn_prediction_project_nn"

# type of the artifact
artifact_type = "Train"

# %%
# configure logging
logging.basicConfig(level=logging.INFO,
                    format="%(asctime)s %(message)s",
                    datefmt='%d-%m-%Y %H:%M:%S')

# reference for a logging obj
logger = logging.getLogger()

# initiate the wandb project
run = wandb.init(project="churn_prediction_project_nn", job_type="train")

logger.info("Downloading and reading train artifact")
local_path = run.use_artifact(artifact_input_name).file()
df_train = pd.read_csv(local_path)

# Spliting train.csv into train and validation dataset
logger.info("Spliting data into train/val")
# split-out train/validation and test dataset
x_train, x_val, y_train, y_val = train_test_split(df_train.drop(labels=stratify,axis=1),
                                                  df_train[stratify],
                                                  test_size=val_size,
                                                  random_state=seed,
                                                  shuffle=True,
                                                  stratify=df_train[stratify])
# Out:
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220714_121622-xwvadi9a</code>
# Syncing run <strong><a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/xwvadi9a" target="_blank">sparkling-field-13</a></strong> to <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 14-07-2022 12:16:27 Downloading and reading train artifact
# 14-07-2022 12:16:28 Spliting data into train/val

# %%
logger.info("x train: {}".format(x_train.shape))
logger.info("y train: {}".format(y_train.shape))
logger.info("x val: {}".format(x_val.shape))
logger.info("y val: {}".format(y_val.shape))
# Out:
# 14-07-2022 12:16:28 x train: (4900, 10)
# 14-07-2022 12:16:28 y train: (4900,)
# 14-07-2022 12:16:28 x val: (2100, 10)
# 14-07-2022 12:16:28 y val: (2100,)

# %% [markdown]
# ### 4.2 Data Preparation

# %% [markdown]
# #### 4.2.1 Outlier Removal

# %%
logger.info("Outlier Removal")
# temporary variable
x = x_train.select_dtypes("float64").copy()

# identify outlier in the dataset
lof = LocalOutlierFactor()
outlier = lof.fit_predict(x)
mask = outlier != -1
# Out:
# 14-07-2022 12:16:38 Outlier Removal

# %%
logger.info("x_train shape [original]: {}".format(x_train.shape))
logger.info("x_train shape [outlier removal]: {}".format(x_train.loc[mask,:].shape))
# Out:
# 14-07-2022 12:16:38 x_train shape [original]: (4900, 10)
# 14-07-2022 12:16:38 x_train shape [outlier removal]: (4882, 10)

# %%
logger.info("y_train shape [original]: {}".format(y_train.shape))
logger.info("y_train shape [outlier removal]: {}".format(y_train.loc[mask].shape))
# Out:
# 14-07-2022 12:16:38 y_train shape [original]: (4900,)
# 14-07-2022 12:16:38 y_train shape [outlier removal]: (4882,)

# %%
# AVOID data leakage and you should not do this procedure in the preprocessing stage
# Note that we did not perform this procedure in the validation set
x_train = x_train.loc[mask,:].copy()
y_train = y_train[mask].copy()

# %% [markdown]
# #### 4.2.2 Target Variable Encoding

# %% [markdown]
# In this case, the target variable is already encoded, but let's create an encoder to transform the numeric variable into categorical.

# %%
logger.info("Encoding a Target Variable")

# define a categorical encoding for target variable
le = LabelEncoder()
le.fit(["Contiuned", "Exited"])
teste = le.inverse_transform(y_train)
# Out:
# 14-07-2022 12:16:38 Encoding a Target Variable

# %% [markdown]
# ### 4.3 Creating a Data Transform Pipeline

# %% [markdown]
# #### 4.3.1 Transformers

# %%
class FeatureSelector(BaseEstimator, TransformerMixin):
    # Class Constructor
    def __init__(self, feature_names):
        self.feature_names = feature_names
        
    # Return self nothing to do here
    def fit(self, X, y=None):
        return self
    
    # Method that describes what tis custom transformer need to do
    def transform(self, X, y=None):
        return X[self.feature_names]
    
# Handling categorical features
class CategoricalTransformer(BaseEstimator, TransformerMixin):
    # Class constructor method that takes one boolean as argument
    def __init__(self, new_features=True, colnames=None):
        self.new_features = new_features
        self.colnames = colnames
        
    # Return self nothing else to do here
    def fit(self, X, y=None):
        return self
    
    def get_feature_names_out(self):
        return self.colnames.tolist()
    
    # Transformer method we wrote for this transformer
    def transform(self, X, y=None):
        df = pd.DataFrame(X, columns=self.colnames)
        
        # Remove white space in categorical features
        df = df.apply(lambda row: row.str.strip())
        
        # customize feature?
        # How can I identify what needs to be modified? EDA!!!!!!
        if self.new_features:
            
            # replace ? with unknown
            edit_cols = ['Geography', 'Gender']
            for col in edit_cols:
                df.loc[df[col].str.contains("\?"), col] = 'unknown'
        
        # update column names
        self.colnames = df.columns
        df = pd.DataFrame(X, columns=self.colnames)
        
        return df

# transform numerical features
class NumericalTransformer(BaseEstimator, TransformerMixin):
    # Class constructor method that takes a model parameter as its argument
    # model 0: minmax
    # model 1: standard
    # model 2: without scaler
    def __init__(self, model=0, colnames=None):
        self.model = model
        self.colnames = colnames
        self.scaler = None

    # Fit is used only to learn statistical about Scalers
    def fit(self, X, y=None):
        df = pd.DataFrame(X, columns=self.colnames)
        
        # minmax
        if self.model == 0:
            self.scaler = MinMaxScaler()
            self.scaler.fit(df)
        # standard scaler
        elif self.model == 1:
            self.scaler = StandardScaler()
            self.scaler.fit(df)
        return self

    # return columns names after transformation
    def get_feature_names_out(self):
        return self.colnames

    # Transformer method we wrote for this transformer
    # Use fitted scalers
    def transform(self, X, y=None):
        df = pd.DataFrame(X, columns=self.colnames)
        
        # update columns name
        self.colnames = df.columns.tolist()

        # minmax
        if self.model == 0:
            # transform data
            df = self.scaler.transform(df)
        elif self.model == 1:
            # transform data
            df = self.scaler.transform(df)
        else:
            df = df.values

        return df

# %% [markdown]
# #### 4.3.2 Holdout Pipeline

# %%
# model = 0 (min-max), 1 (z-score), 2 (without normalization)
numerical_model = 1

# Categrical features to pass down the categorical pipeline
categorical_features = x_train.select_dtypes("object").columns.to_list()

# Numerical features to pass down the numerical pipeline
numerical_features = x_train.select_dtypes(["int64","float"]).columns.to_list()

# Defining the steps for the categorical pipeline
categorical_pipeline = Pipeline(steps=[('cat_selector', FeatureSelector(categorical_features)),
                                       ('imputer_cat', SimpleImputer(strategy="most_frequent")),
                                       ('cat_transformer', CategoricalTransformer(colnames=categorical_features)),
                                       ('cat_encoder', OneHotEncoder(sparse=False, drop="first"))])

# Defining the steps in the numerical pipeline
numerical_pipeline = Pipeline(steps=[('num_selector', FeatureSelector(numerical_features)),
                                     ('imputer_num', SimpleImputer(strategy="median")),
                                     ('num_transformer', NumericalTransformer(numerical_model, 
                                                                              colnames=numerical_features))])

# Combine numerical and categorical pieplines into one full big pipeline horizontally
pipe = FeatureUnion(transformer_list=[('cat_pipeline', categorical_pipeline),
                                                             ('num_pipeline', numerical_pipeline)])

# %% [markdown]
# #### 4.3.3 Transforming

# %%
x_train_orig = x_train
x_val_orig = x_val

# %%
# Transforming
logger.info("Transforming")
x_train = pipe.fit_transform(x_train_orig, y_train)
x_val = pipe.transform(x_val_orig)
# Out:
# 14-07-2022 12:17:18 Transforming

# %% [markdown]
# ### 4.4 Base Model

# %%
class MyCustomCallback(tf.keras.callbacks.Callback):

  def on_train_begin(self, batch, logs=None):
    self.begins = time.time()
    print('Training: begins at {}'.format(datetime.datetime.now(pytz.timezone('America/Fortaleza')).strftime("%a, %d %b %Y %H:%M:%S")))

  def on_train_end(self, logs=None):
    print('Training: ends at {}'.format(datetime.datetime.now(pytz.timezone('America/Fortaleza')).strftime("%a, %d %b %Y %H:%M:%S")))
    print('Duration: {:.2f} seconds'.format(time.time() - self.begins))

# %%
N, D = x_train.shape

# %%
# Instantiate a simple classification model
model = tf.keras.Sequential([
  tf.keras.layers.Dense(13, kernel_initializer = 'uniform', activation='relu', input_dim = D),
  tf.keras.layers.Dense(12, kernel_initializer = 'uniform', activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# Instantiate a logistic loss function that expects integer targets.
loss = tf.keras.losses.BinaryCrossentropy()

# Instantiate an accuracy metric.
accuracy = tf.keras.metrics.BinaryAccuracy()

# Instantiate an optimizer.
#optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.02)

# configure the optimizer, loss, and metrics to monitor.
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[accuracy])

# training 
history = model.fit(x=x_train,
                    y=y_train,
                    batch_size=64,
                    epochs=5,
                    validation_data=(x_val,y_val),
                    callbacks=[MyCustomCallback()],
                    verbose=1)
# Out:
# Training: begins at Thu, 14 Jul 2022 09:18:01
# Epoch 1/5
# 77/77 [==============================] - 3s 13ms/step - loss: 0.4662 - binary_accuracy: 0.7909 - val_loss: 0.4361 - val_binary_accuracy: 0.7962
# Epoch 2/5
# 77/77 [==============================] - 0s 5ms/step - loss: 0.4372 - binary_accuracy: 0.8034 - val_loss: 0.4211 - val_binary_accuracy: 0.8300
# Epoch 3/5
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4293 - binary_accuracy: 0.8259 - val_loss: 0.4175 - val_binary_accuracy: 0.8290
# Epoch 4/5
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4262 - binary_accuracy: 0.8273 - val_loss: 0.4199 - val_binary_accuracy: 0.8333
# Epoch 5/5
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4225 - binary_accuracy: 0.8286 - val_loss: 0.4109 - val_binary_accuracy: 0.8314
# Training: ends at Thu, 14 Jul 2022 09:18:05
# Duration: 4.02 seconds

# %%
loss, acc = model.evaluate(x=x_train,y=y_train, batch_size=32)
print('Train loss: %.4f - acc: %.4f' % (loss, acc))

loss_, acc_ = model.evaluate(x=x_val,y=y_val, batch_size=32)
print('Test loss: %.4f - acc: %.4f' % (loss_, acc_))
# Out:
# 153/153 [==============================] - 0s 1ms/step - loss: 0.4152 - binary_accuracy: 0.8327
# Train loss: 0.4152 - acc: 0.8327
# 66/66 [==============================] - 0s 1ms/step - loss: 0.4109 - binary_accuracy: 0.8314
# Test loss: 0.4109 - acc: 0.8314

# %%
predict = model.predict(x_val)

# %%
predict
# Out:
# array([[0.05999011],
#        [0.07585558],
#        [0.33386686],
#        ...,
#        [0.10198307],
#        [0.21416071],
#        [0.07554609]], dtype=float32)

# %% [markdown]
# --------------------------

# %% [markdown]
# ### 4.5 Hyperparameter Tuning

# %% [markdown]
# #### 4.5.1 Monitoring a neural network

# %%
# Default values for hyperparameters
defaults = dict(layer_1 = 13,
                layer_2 = 12,
                learn_rate = 0.02218,
                batch_size = 64,
                epoch = 10)

wandb.init(project=project_name, config= defaults, name="run_01")
config = wandb.config
# Out:
# Finishing last run (ID:xwvadi9a) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">sparkling-field-13</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/xwvadi9a" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/xwvadi9a</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220714_121622-xwvadi9a/logs</code>
# Successfully finished last run (ID:xwvadi9a). Initializing new run:<br/>
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220714_122316-1nrpmwe7</code>
# Syncing run <strong><a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1nrpmwe7" target="_blank">run_01</a></strong> to <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# Instantiate a simple classification model
model = tf.keras.Sequential([
  tf.keras.layers.Dense(config.layer_1, activation=tf.nn.relu),
  tf.keras.layers.Dense(config.layer_2, activation=tf.nn.relu),
  tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

# Instantiate a logistic loss function that expects integer targets.
loss = tf.keras.losses.BinaryCrossentropy()

# Instantiate an accuracy metric.
accuracy = tf.keras.metrics.BinaryAccuracy()

# Instantiate an optimizer.
optimizer = tf.keras.optimizers.SGD(learning_rate=config.learn_rate)

# configure the optimizer, loss, and metrics to monitor.
model.compile(optimizer=optimizer, loss=loss, metrics=[accuracy])

# %%
# %%wandb
# # Add WandbCallback() to the fit function
# model.fit(x=x_train,
#           y=y_train,
#           batch_size=config.batch_size,
#           epochs=config.epoch,
#           validation_data=(x_val,y_val),
#           callbacks=[WandbCallback(log_weights=True)],
#           verbose=0)
# Out:
# <iframe src="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1nrpmwe7?jupyter=true" style="border:none;width:100%;height:420px;"></iframe>
# wandb: WARNING The save_model argument by default saves the model in the HDF5 format that cannot save custom objects like subclassed models and custom layers. This behavior will be deprecated in a future release in favor of the SavedModel format. Meanwhile, the HDF5 model is saved as W&B files and the SavedModel as W&B Artifacts.
# wandb: WARNING Unable to compute FLOPs for this model.

# %% [markdown]
# ### 4.5.2 Sweeps

# %%
# The sweep calls this function with each set of hyperparameters
def train():
    # Default values for hyper-parameters we're going to sweep over
    defaults = dict(layer_1 = 13,
                layer_2 = 12,
                learn_rate = 0.02,
                batch_size = 64,
                epoch = 600)
    
    # Initialize a new wandb run
    wandb.init(project=project_name, config= defaults)

    # Config is a variable that holds and saves hyperparameters and inputs
    config = wandb.config
    
    # Instantiate a simple classification model
    model = tf.keras.Sequential([
                                 tf.keras.layers.Dense(config.layer_1, activation=tf.nn.relu, dtype='float64'),
                                 tf.keras.layers.Dense(config.layer_2, activation=tf.nn.relu, dtype='float64'),
                                 tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)
                                 ])

    # Instantiate a logistic loss function that expects integer targets.
    loss = tf.keras.losses.BinaryCrossentropy()

    # Instantiate an accuracy metric.
    accuracy = tf.keras.metrics.BinaryAccuracy()

    # Instantiate an optimizer.
    optimizer = tf.keras.optimizers.SGD(learning_rate=config.learn_rate)

    # configure the optimizer, loss, and metrics to monitor.
    model.compile(optimizer=optimizer, loss=loss, metrics=[accuracy])  

    model.fit(x_train, y_train, batch_size=config.batch_size,
              epochs=config.epoch,
              validation_data=(x_val, y_val),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=100)]
              )

# %%
# Configure the sweep – specify the parameters to search through, the search strategy, the optimization metric et all.
sweep_config = {
    'method': 'random', #grid, random
    'metric': {
      'name': 'binary_accuracy',
      'goal': 'maximize'   
    },
    'parameters': {
        'layer_1': {
            'max': 32,
            'min': 8,
            'distribution': 'int_uniform',
        },
        'layer_2': {
            'max': 32,
            'min': 8,
            'distribution': 'int_uniform',
        },
        'learn_rate': {
            'min': -4,
            'max': -2,
            'distribution': 'log_uniform',  
        },
        'epoch': {
            'values': [300,400,600]
        },
        'batch_size': {
            'values': [32,64]
        }
    }
}

# %%
# Initialize a new sweep
# Arguments:
#     – sweep_config: the sweep config dictionary defined above
#     – entity: Set the username for the sweep
#     – project: Set the project name for the sweep
sweep_id = wandb.sweep(sweep_config, entity=entity_name, project=project_name)
# Out:
# wandb: WARNING Malformed sweep config detected! This may cause your sweep to behave in unexpected ways.
# wandb: WARNING To avoid this, please fix the sweep config schema violations below:
# wandb: WARNING   Violation 1. learn_rate uses log_uniform, where min/max specify base-e exponents. Use log_uniform_values to specify limit values.
# Create sweep with ID: 9mnf75ns
# Sweep URL: https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9mnf75ns

# %%
# Initialize a new sweep
# Arguments:
#     – sweep_id: the sweep_id to run - this was returned above by wandb.sweep()
#     – function: function that defines your model architecture and trains it
wandb.agent(sweep_id = sweep_id, function=train,count=2)
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: Agent Starting Run: q3dvclh5 with config:
# wandb: 	batch_size: 32
# wandb: 	epoch: 300
# wandb: 	layer_1: 14
# wandb: 	layer_2: 31
# wandb: 	learn_rate: 0.12156142714535824
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220714_122447-q3dvclh5</code>
# Syncing run <strong><a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/q3dvclh5" target="_blank">snowy-sweep-1</a></strong> to <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9mnf75ns" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9mnf75ns</a>
# wandb: WARNING Unable to compute FLOPs for this model.
# Epoch 1/300
#   1/153 [..............................] - ETA: 2:12 - loss: 0.6639 - binary_accuracy: 0.5938WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0014s vs `on_train_batch_end` time: 0.0022s). Check your callbacks.
# 14-07-2022 12:24:55 Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0014s vs `on_train_batch_end` time: 0.0022s). Check your callbacks.
# 153/153 [==============================] - 1s 4ms/step - loss: 0.4915 - binary_accuracy: 0.7933 - val_loss: 0.4457 - val_binary_accuracy: 0.8062 - _timestamp: 1657801495.0000 - _runtime: 8.0000
# Epoch 2/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.4309 - binary_accuracy: 0.8183 - val_loss: 0.4022 - val_binary_accuracy: 0.8324 - _timestamp: 1657801496.0000 - _runtime: 9.0000
# Epoch 3/300
# 153/153 [==============================] - 1s 4ms/step - loss: 0.4045 - binary_accuracy: 0.8327 - val_loss: 0.3904 - val_binary_accuracy: 0.8310 - _timestamp: 1657801496.0000 - _runtime: 9.0000
# Epoch 4/300
# 153/153 [==============================] - 1s 4ms/step - loss: 0.3847 - binary_accuracy: 0.8386 - val_loss: 0.3696 - val_binary_accuracy: 0.8471 - _timestamp: 1657801497.0000 - _runtime: 10.0000
# Epoch 5/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3701 - binary_accuracy: 0.8482 - val_loss: 0.3564 - val_binary_accuracy: 0.8510 - _timestamp: 1657801497.0000 - _runtime: 10.0000
# Epoch 6/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3621 - binary_accuracy: 0.8499 - val_loss: 0.3515 - val_binary_accuracy: 0.8557 - _timestamp: 1657801498.0000 - _runtime: 11.0000
# Epoch 7/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3574 - binary_accuracy: 0.8523 - val_loss: 0.3512 - val_binary_accuracy: 0.8552 - _timestamp: 1657801498.0000 - _runtime: 11.0000
# Epoch 8/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3544 - binary_accuracy: 0.8513 - val_loss: 0.3507 - val_binary_accuracy: 0.8457 - _timestamp: 1657801499.0000 - _runtime: 12.0000
# Epoch 9/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3511 - binary_accuracy: 0.8546 - val_loss: 0.3492 - val_binary_accuracy: 0.8505 - _timestamp: 1657801499.0000 - _runtime: 12.0000
# Epoch 10/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3509 - binary_accuracy: 0.8591 - val_loss: 0.3452 - val_binary_accuracy: 0.8524 - _timestamp: 1657801499.0000 - _runtime: 12.0000
# Epoch 11/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3479 - binary_accuracy: 0.8548 - val_loss: 0.3475 - val_binary_accuracy: 0.8529 - _timestamp: 1657801500.0000 - _runtime: 13.0000
# Epoch 12/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3485 - binary_accuracy: 0.8560 - val_loss: 0.3422 - val_binary_accuracy: 0.8543 - _timestamp: 1657801500.0000 - _runtime: 13.0000
# Epoch 13/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3478 - binary_accuracy: 0.8548 - val_loss: 0.3423 - val_binary_accuracy: 0.8581 - _timestamp: 1657801501.0000 - _runtime: 14.0000
# Epoch 14/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3463 - binary_accuracy: 0.8560 - val_loss: 0.3432 - val_binary_accuracy: 0.8557 - _timestamp: 1657801501.0000 - _runtime: 14.0000
# Epoch 15/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3453 - binary_accuracy: 0.8597 - val_loss: 0.3418 - val_binary_accuracy: 0.8576 - _timestamp: 1657801501.0000 - _runtime: 14.0000
# Epoch 16/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3440 - binary_accuracy: 0.8593 - val_loss: 0.3422 - val_binary_accuracy: 0.8524 - _timestamp: 1657801502.0000 - _runtime: 15.0000
# Epoch 17/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3410 - binary_accuracy: 0.8583 - val_loss: 0.3459 - val_binary_accuracy: 0.8562 - _timestamp: 1657801502.0000 - _runtime: 15.0000
# Epoch 18/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3434 - binary_accuracy: 0.8587 - val_loss: 0.3413 - val_binary_accuracy: 0.8538 - _timestamp: 1657801503.0000 - _runtime: 16.0000
# Epoch 19/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3415 - binary_accuracy: 0.8593 - val_loss: 0.3542 - val_binary_accuracy: 0.8495 - _timestamp: 1657801503.0000 - _runtime: 16.0000
# Epoch 20/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3417 - binary_accuracy: 0.8599 - val_loss: 0.3493 - val_binary_accuracy: 0.8605 - _timestamp: 1657801503.0000 - _runtime: 16.0000
# Epoch 21/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3417 - binary_accuracy: 0.8597 - val_loss: 0.3406 - val_binary_accuracy: 0.8614 - _timestamp: 1657801504.0000 - _runtime: 17.0000
# Epoch 22/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3395 - binary_accuracy: 0.8599 - val_loss: 0.3603 - val_binary_accuracy: 0.8476 - _timestamp: 1657801504.0000 - _runtime: 17.0000
# Epoch 23/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3400 - binary_accuracy: 0.8574 - val_loss: 0.3488 - val_binary_accuracy: 0.8505 - _timestamp: 1657801505.0000 - _runtime: 18.0000
# Epoch 24/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3385 - binary_accuracy: 0.8595 - val_loss: 0.3411 - val_binary_accuracy: 0.8581 - _timestamp: 1657801505.0000 - _runtime: 18.0000
# Epoch 25/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3396 - binary_accuracy: 0.8613 - val_loss: 0.3501 - val_binary_accuracy: 0.8500 - _timestamp: 1657801505.0000 - _runtime: 18.0000
# Epoch 26/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3366 - binary_accuracy: 0.8621 - val_loss: 0.3464 - val_binary_accuracy: 0.8543 - _timestamp: 1657801506.0000 - _runtime: 19.0000
# Epoch 27/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3374 - binary_accuracy: 0.8562 - val_loss: 0.3444 - val_binary_accuracy: 0.8519 - _timestamp: 1657801506.0000 - _runtime: 19.0000
# Epoch 28/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3358 - binary_accuracy: 0.8626 - val_loss: 0.3423 - val_binary_accuracy: 0.8557 - _timestamp: 1657801507.0000 - _runtime: 20.0000
# Epoch 29/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3370 - binary_accuracy: 0.8587 - val_loss: 0.3475 - val_binary_accuracy: 0.8476 - _timestamp: 1657801507.0000 - _runtime: 20.0000
# Epoch 30/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3364 - binary_accuracy: 0.8611 - val_loss: 0.3437 - val_binary_accuracy: 0.8538 - _timestamp: 1657801507.0000 - _runtime: 20.0000
# Epoch 31/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3353 - binary_accuracy: 0.8619 - val_loss: 0.3451 - val_binary_accuracy: 0.8590 - _timestamp: 1657801508.0000 - _runtime: 21.0000
# Epoch 32/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3335 - binary_accuracy: 0.8632 - val_loss: 0.3470 - val_binary_accuracy: 0.8490 - _timestamp: 1657801508.0000 - _runtime: 21.0000
# Epoch 33/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3358 - binary_accuracy: 0.8599 - val_loss: 0.3469 - val_binary_accuracy: 0.8624 - _timestamp: 1657801509.0000 - _runtime: 22.0000
# Epoch 34/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3351 - binary_accuracy: 0.8619 - val_loss: 0.3447 - val_binary_accuracy: 0.8571 - _timestamp: 1657801509.0000 - _runtime: 22.0000
# Epoch 35/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3347 - binary_accuracy: 0.8630 - val_loss: 0.3521 - val_binary_accuracy: 0.8490 - _timestamp: 1657801509.0000 - _runtime: 22.0000
# Epoch 36/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3340 - binary_accuracy: 0.8605 - val_loss: 0.3414 - val_binary_accuracy: 0.8557 - _timestamp: 1657801510.0000 - _runtime: 23.0000
# Epoch 37/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3333 - binary_accuracy: 0.8607 - val_loss: 0.3492 - val_binary_accuracy: 0.8538 - _timestamp: 1657801510.0000 - _runtime: 23.0000
# Epoch 38/300
# 153/153 [==============================] - 1s 4ms/step - loss: 0.3326 - binary_accuracy: 0.8621 - val_loss: 0.3420 - val_binary_accuracy: 0.8562 - _timestamp: 1657801511.0000 - _runtime: 24.0000
# Epoch 39/300
# 153/153 [==============================] - 1s 4ms/step - loss: 0.3327 - binary_accuracy: 0.8624 - val_loss: 0.3500 - val_binary_accuracy: 0.8524 - _timestamp: 1657801511.0000 - _runtime: 24.0000
# Epoch 40/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3332 - binary_accuracy: 0.8640 - val_loss: 0.3463 - val_binary_accuracy: 0.8514 - _timestamp: 1657801512.0000 - _runtime: 25.0000
# Epoch 41/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3306 - binary_accuracy: 0.8646 - val_loss: 0.3436 - val_binary_accuracy: 0.8557 - _timestamp: 1657801512.0000 - _runtime: 25.0000
# Epoch 42/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3311 - binary_accuracy: 0.8638 - val_loss: 0.3456 - val_binary_accuracy: 0.8552 - _timestamp: 1657801512.0000 - _runtime: 25.0000
# Epoch 43/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3301 - binary_accuracy: 0.8632 - val_loss: 0.3436 - val_binary_accuracy: 0.8595 - _timestamp: 1657801513.0000 - _runtime: 26.0000
# Epoch 44/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3299 - binary_accuracy: 0.8634 - val_loss: 0.3472 - val_binary_accuracy: 0.8581 - _timestamp: 1657801513.0000 - _runtime: 26.0000
# Epoch 45/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3301 - binary_accuracy: 0.8605 - val_loss: 0.3475 - val_binary_accuracy: 0.8529 - _timestamp: 1657801514.0000 - _runtime: 27.0000
# Epoch 46/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3292 - binary_accuracy: 0.8640 - val_loss: 0.3573 - val_binary_accuracy: 0.8476 - _timestamp: 1657801514.0000 - _runtime: 27.0000
# Epoch 47/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3297 - binary_accuracy: 0.8607 - val_loss: 0.3465 - val_binary_accuracy: 0.8533 - _timestamp: 1657801514.0000 - _runtime: 27.0000
# Epoch 48/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3288 - binary_accuracy: 0.8656 - val_loss: 0.3422 - val_binary_accuracy: 0.8571 - _timestamp: 1657801515.0000 - _runtime: 28.0000
# Epoch 49/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3279 - binary_accuracy: 0.8660 - val_loss: 0.3478 - val_binary_accuracy: 0.8571 - _timestamp: 1657801515.0000 - _runtime: 28.0000
# Epoch 50/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3260 - binary_accuracy: 0.8642 - val_loss: 0.3456 - val_binary_accuracy: 0.8552 - _timestamp: 1657801516.0000 - _runtime: 29.0000
# Epoch 51/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3284 - binary_accuracy: 0.8632 - val_loss: 0.3418 - val_binary_accuracy: 0.8590 - _timestamp: 1657801516.0000 - _runtime: 29.0000
# Epoch 52/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3265 - binary_accuracy: 0.8660 - val_loss: 0.3518 - val_binary_accuracy: 0.8538 - _timestamp: 1657801516.0000 - _runtime: 29.0000
# Epoch 53/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3268 - binary_accuracy: 0.8644 - val_loss: 0.3519 - val_binary_accuracy: 0.8519 - _timestamp: 1657801517.0000 - _runtime: 30.0000
# Epoch 54/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3267 - binary_accuracy: 0.8634 - val_loss: 0.3494 - val_binary_accuracy: 0.8514 - _timestamp: 1657801517.0000 - _runtime: 30.0000
# Epoch 55/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3277 - binary_accuracy: 0.8617 - val_loss: 0.3454 - val_binary_accuracy: 0.8576 - _timestamp: 1657801518.0000 - _runtime: 31.0000
# Epoch 56/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3251 - binary_accuracy: 0.8662 - val_loss: 0.3494 - val_binary_accuracy: 0.8562 - _timestamp: 1657801518.0000 - _runtime: 31.0000
# Epoch 57/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3261 - binary_accuracy: 0.8628 - val_loss: 0.3506 - val_binary_accuracy: 0.8505 - _timestamp: 1657801518.0000 - _runtime: 31.0000
# Epoch 58/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3248 - binary_accuracy: 0.8667 - val_loss: 0.3868 - val_binary_accuracy: 0.8352 - _timestamp: 1657801519.0000 - _runtime: 32.0000
# Epoch 59/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3257 - binary_accuracy: 0.8607 - val_loss: 0.3619 - val_binary_accuracy: 0.8529 - _timestamp: 1657801519.0000 - _runtime: 32.0000
# Epoch 60/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3251 - binary_accuracy: 0.8626 - val_loss: 0.3470 - val_binary_accuracy: 0.8562 - _timestamp: 1657801519.0000 - _runtime: 32.0000
# Epoch 61/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3252 - binary_accuracy: 0.8644 - val_loss: 0.3498 - val_binary_accuracy: 0.8552 - _timestamp: 1657801520.0000 - _runtime: 33.0000
# Epoch 62/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3252 - binary_accuracy: 0.8632 - val_loss: 0.3525 - val_binary_accuracy: 0.8543 - _timestamp: 1657801520.0000 - _runtime: 33.0000
# Epoch 63/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3249 - binary_accuracy: 0.8652 - val_loss: 0.3476 - val_binary_accuracy: 0.8614 - _timestamp: 1657801521.0000 - _runtime: 34.0000
# Epoch 64/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3225 - binary_accuracy: 0.8630 - val_loss: 0.3485 - val_binary_accuracy: 0.8552 - _timestamp: 1657801521.0000 - _runtime: 34.0000
# Epoch 65/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3233 - binary_accuracy: 0.8642 - val_loss: 0.3501 - val_binary_accuracy: 0.8533 - _timestamp: 1657801521.0000 - _runtime: 34.0000
# Epoch 66/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3239 - binary_accuracy: 0.8671 - val_loss: 0.3482 - val_binary_accuracy: 0.8590 - _timestamp: 1657801522.0000 - _runtime: 35.0000
# Epoch 67/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3227 - binary_accuracy: 0.8636 - val_loss: 0.3485 - val_binary_accuracy: 0.8567 - _timestamp: 1657801522.0000 - _runtime: 35.0000
# Epoch 68/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3210 - binary_accuracy: 0.8630 - val_loss: 0.3612 - val_binary_accuracy: 0.8548 - _timestamp: 1657801523.0000 - _runtime: 36.0000
# Epoch 69/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3232 - binary_accuracy: 0.8667 - val_loss: 0.3535 - val_binary_accuracy: 0.8519 - _timestamp: 1657801523.0000 - _runtime: 36.0000
# Epoch 70/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3227 - binary_accuracy: 0.8677 - val_loss: 0.3545 - val_binary_accuracy: 0.8543 - _timestamp: 1657801523.0000 - _runtime: 36.0000
# Epoch 71/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3218 - binary_accuracy: 0.8658 - val_loss: 0.3539 - val_binary_accuracy: 0.8533 - _timestamp: 1657801524.0000 - _runtime: 37.0000
# Epoch 72/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3203 - binary_accuracy: 0.8681 - val_loss: 0.3555 - val_binary_accuracy: 0.8557 - _timestamp: 1657801524.0000 - _runtime: 37.0000
# Epoch 73/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3221 - binary_accuracy: 0.8646 - val_loss: 0.3586 - val_binary_accuracy: 0.8514 - _timestamp: 1657801524.0000 - _runtime: 37.0000
# Epoch 74/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3218 - binary_accuracy: 0.8664 - val_loss: 0.3568 - val_binary_accuracy: 0.8548 - _timestamp: 1657801525.0000 - _runtime: 38.0000
# Epoch 75/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3215 - binary_accuracy: 0.8644 - val_loss: 0.3497 - val_binary_accuracy: 0.8567 - _timestamp: 1657801525.0000 - _runtime: 38.0000
# Epoch 76/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3187 - binary_accuracy: 0.8638 - val_loss: 0.3561 - val_binary_accuracy: 0.8538 - _timestamp: 1657801526.0000 - _runtime: 39.0000
# Epoch 77/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3186 - binary_accuracy: 0.8656 - val_loss: 0.3590 - val_binary_accuracy: 0.8486 - _timestamp: 1657801526.0000 - _runtime: 39.0000
# Epoch 78/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3187 - binary_accuracy: 0.8652 - val_loss: 0.3566 - val_binary_accuracy: 0.8571 - _timestamp: 1657801526.0000 - _runtime: 39.0000
# Epoch 79/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3199 - binary_accuracy: 0.8638 - val_loss: 0.3535 - val_binary_accuracy: 0.8552 - _timestamp: 1657801527.0000 - _runtime: 40.0000
# Epoch 80/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3174 - binary_accuracy: 0.8638 - val_loss: 0.3537 - val_binary_accuracy: 0.8567 - _timestamp: 1657801527.0000 - _runtime: 40.0000
# Epoch 81/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3173 - binary_accuracy: 0.8673 - val_loss: 0.3528 - val_binary_accuracy: 0.8543 - _timestamp: 1657801528.0000 - _runtime: 41.0000
# Epoch 82/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3170 - binary_accuracy: 0.8677 - val_loss: 0.3551 - val_binary_accuracy: 0.8581 - _timestamp: 1657801528.0000 - _runtime: 41.0000
# Epoch 83/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3173 - binary_accuracy: 0.8667 - val_loss: 0.3576 - val_binary_accuracy: 0.8543 - _timestamp: 1657801528.0000 - _runtime: 41.0000
# Epoch 84/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3176 - binary_accuracy: 0.8646 - val_loss: 0.3534 - val_binary_accuracy: 0.8567 - _timestamp: 1657801529.0000 - _runtime: 42.0000
# Epoch 85/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3154 - binary_accuracy: 0.8646 - val_loss: 0.3554 - val_binary_accuracy: 0.8538 - _timestamp: 1657801529.0000 - _runtime: 42.0000
# Epoch 86/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3164 - binary_accuracy: 0.8656 - val_loss: 0.3541 - val_binary_accuracy: 0.8538 - _timestamp: 1657801530.0000 - _runtime: 43.0000
# Epoch 87/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3167 - binary_accuracy: 0.8675 - val_loss: 0.3563 - val_binary_accuracy: 0.8533 - _timestamp: 1657801530.0000 - _runtime: 43.0000
# Epoch 88/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3164 - binary_accuracy: 0.8685 - val_loss: 0.3585 - val_binary_accuracy: 0.8505 - _timestamp: 1657801531.0000 - _runtime: 44.0000
# Epoch 89/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3143 - binary_accuracy: 0.8697 - val_loss: 0.3619 - val_binary_accuracy: 0.8533 - _timestamp: 1657801531.0000 - _runtime: 44.0000
# Epoch 90/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3158 - binary_accuracy: 0.8658 - val_loss: 0.3685 - val_binary_accuracy: 0.8452 - _timestamp: 1657801531.0000 - _runtime: 44.0000
# Epoch 91/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3160 - binary_accuracy: 0.8613 - val_loss: 0.3605 - val_binary_accuracy: 0.8538 - _timestamp: 1657801532.0000 - _runtime: 45.0000
# Epoch 92/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3139 - binary_accuracy: 0.8638 - val_loss: 0.3607 - val_binary_accuracy: 0.8567 - _timestamp: 1657801532.0000 - _runtime: 45.0000
# Epoch 93/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3151 - binary_accuracy: 0.8660 - val_loss: 0.3618 - val_binary_accuracy: 0.8476 - _timestamp: 1657801532.0000 - _runtime: 45.0000
# Epoch 94/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3146 - binary_accuracy: 0.8646 - val_loss: 0.3668 - val_binary_accuracy: 0.8505 - _timestamp: 1657801533.0000 - _runtime: 46.0000
# Epoch 95/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3148 - binary_accuracy: 0.8667 - val_loss: 0.3892 - val_binary_accuracy: 0.8381 - _timestamp: 1657801533.0000 - _runtime: 46.0000
# Epoch 96/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3149 - binary_accuracy: 0.8652 - val_loss: 0.3628 - val_binary_accuracy: 0.8533 - _timestamp: 1657801534.0000 - _runtime: 47.0000
# Epoch 97/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3126 - binary_accuracy: 0.8685 - val_loss: 0.3646 - val_binary_accuracy: 0.8557 - _timestamp: 1657801534.0000 - _runtime: 47.0000
# Epoch 98/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3154 - binary_accuracy: 0.8644 - val_loss: 0.3802 - val_binary_accuracy: 0.8405 - _timestamp: 1657801535.0000 - _runtime: 48.0000
# Epoch 99/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3116 - binary_accuracy: 0.8683 - val_loss: 0.3747 - val_binary_accuracy: 0.8448 - _timestamp: 1657801535.0000 - _runtime: 48.0000
# Epoch 100/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3126 - binary_accuracy: 0.8675 - val_loss: 0.3608 - val_binary_accuracy: 0.8562 - _timestamp: 1657801535.0000 - _runtime: 48.0000
# Epoch 101/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3119 - binary_accuracy: 0.8701 - val_loss: 0.3684 - val_binary_accuracy: 0.8486 - _timestamp: 1657801536.0000 - _runtime: 49.0000
# Epoch 102/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3114 - binary_accuracy: 0.8701 - val_loss: 0.3596 - val_binary_accuracy: 0.8529 - _timestamp: 1657801536.0000 - _runtime: 49.0000
# Epoch 103/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3110 - binary_accuracy: 0.8695 - val_loss: 0.3603 - val_binary_accuracy: 0.8552 - _timestamp: 1657801537.0000 - _runtime: 50.0000
# Epoch 104/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3099 - binary_accuracy: 0.8664 - val_loss: 0.3683 - val_binary_accuracy: 0.8524 - _timestamp: 1657801537.0000 - _runtime: 50.0000
# Epoch 105/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3096 - binary_accuracy: 0.8667 - val_loss: 0.3740 - val_binary_accuracy: 0.8438 - _timestamp: 1657801537.0000 - _runtime: 50.0000
# Epoch 106/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3110 - binary_accuracy: 0.8673 - val_loss: 0.3633 - val_binary_accuracy: 0.8548 - _timestamp: 1657801538.0000 - _runtime: 51.0000
# Epoch 107/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3109 - binary_accuracy: 0.8658 - val_loss: 0.3631 - val_binary_accuracy: 0.8581 - _timestamp: 1657801538.0000 - _runtime: 51.0000
# Epoch 108/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3079 - binary_accuracy: 0.8695 - val_loss: 0.3737 - val_binary_accuracy: 0.8510 - _timestamp: 1657801539.0000 - _runtime: 52.0000
# Epoch 109/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3101 - binary_accuracy: 0.8683 - val_loss: 0.3680 - val_binary_accuracy: 0.8524 - _timestamp: 1657801539.0000 - _runtime: 52.0000
# Epoch 110/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3094 - binary_accuracy: 0.8650 - val_loss: 0.3789 - val_binary_accuracy: 0.8467 - _timestamp: 1657801539.0000 - _runtime: 52.0000
# Epoch 111/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3109 - binary_accuracy: 0.8654 - val_loss: 0.3718 - val_binary_accuracy: 0.8557 - _timestamp: 1657801540.0000 - _runtime: 53.0000
# Epoch 112/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3093 - binary_accuracy: 0.8675 - val_loss: 0.3727 - val_binary_accuracy: 0.8495 - _timestamp: 1657801540.0000 - _runtime: 53.0000
# Epoch 113/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3092 - binary_accuracy: 0.8707 - val_loss: 0.3653 - val_binary_accuracy: 0.8505 - _timestamp: 1657801541.0000 - _runtime: 54.0000
# Epoch 114/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3082 - binary_accuracy: 0.8677 - val_loss: 0.3666 - val_binary_accuracy: 0.8567 - _timestamp: 1657801541.0000 - _runtime: 54.0000
# Epoch 115/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3094 - binary_accuracy: 0.8644 - val_loss: 0.3740 - val_binary_accuracy: 0.8500 - _timestamp: 1657801541.0000 - _runtime: 54.0000
# Epoch 116/300
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3080 - binary_accuracy: 0.8683 - val_loss: 0.3681 - val_binary_accuracy: 0.8524 - _timestamp: 1657801542.0000 - _runtime: 55.0000
# Epoch 117/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3074 - binary_accuracy: 0.8681 - val_loss: 0.3965 - val_binary_accuracy: 0.8348 - _timestamp: 1657801542.0000 - _runtime: 55.0000
# Epoch 118/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3091 - binary_accuracy: 0.8669 - val_loss: 0.3691 - val_binary_accuracy: 0.8552 - _timestamp: 1657801543.0000 - _runtime: 56.0000
# Epoch 119/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3076 - binary_accuracy: 0.8695 - val_loss: 0.3854 - val_binary_accuracy: 0.8410 - _timestamp: 1657801543.0000 - _runtime: 56.0000
# Epoch 120/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3094 - binary_accuracy: 0.8699 - val_loss: 0.3745 - val_binary_accuracy: 0.8514 - _timestamp: 1657801544.0000 - _runtime: 57.0000
# Epoch 121/300
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3059 - binary_accuracy: 0.8687 - val_loss: 0.3712 - val_binary_accuracy: 0.8538 - _timestamp: 1657801544.0000 - _runtime: 57.0000
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.024 MB of 0.024 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>binary_accuracy</td><td>▁▅▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇▇▇▇████▇████████████</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_binary_accuracy</td><td>▁▆▇▇█▇▇▆▇███▇██▇▇▇█▇▇▇▇▇▇▇▇█▇▆▆▇▆▇▆▇██▅▇</td></tr><tr><td>val_loss</td><td>█▃▂▁▁▁▂▂▂▁▁▁▁▁▁▁▁▂▁▂▂▂▂▂▂▂▂▂▂▃▂▂▃▂▃▃▃▃▅▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>20</td></tr><tr><td>best_val_loss</td><td>0.34055</td></tr><tr><td>binary_accuracy</td><td>0.8687</td></tr><tr><td>epoch</td><td>120</td></tr><tr><td>loss</td><td>0.30595</td></tr><tr><td>val_binary_accuracy</td><td>0.85381</td></tr><tr><td>val_loss</td><td>0.37119</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">snowy-sweep-1</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/q3dvclh5" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/q3dvclh5</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220714_122447-q3dvclh5/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 1zcuptg0 with config:
# wandb: 	batch_size: 64
# wandb: 	epoch: 300
# wandb: 	layer_1: 30
# wandb: 	layer_2: 9
# wandb: 	learn_rate: 0.02177180316952747
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220714_122604-1zcuptg0</code>
# Syncing run <strong><a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1zcuptg0" target="_blank">radiant-sweep-2</a></strong> to <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9mnf75ns" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9mnf75ns</a>
# wandb: WARNING Unable to compute FLOPs for this model.
# Epoch 1/300
# 77/77 [==============================] - 1s 4ms/step - loss: 0.6358 - binary_accuracy: 0.6860 - val_loss: 0.5488 - val_binary_accuracy: 0.7957 - _timestamp: 1657801570.0000 - _runtime: 6.0000
# Epoch 2/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5199 - binary_accuracy: 0.7970 - val_loss: 0.5015 - val_binary_accuracy: 0.7962 - _timestamp: 1657801570.0000 - _runtime: 6.0000
# Epoch 3/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4887 - binary_accuracy: 0.7968 - val_loss: 0.4801 - val_binary_accuracy: 0.7962 - _timestamp: 1657801571.0000 - _runtime: 7.0000
# Epoch 4/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4704 - binary_accuracy: 0.7968 - val_loss: 0.4641 - val_binary_accuracy: 0.7976 - _timestamp: 1657801571.0000 - _runtime: 7.0000
# Epoch 5/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4551 - binary_accuracy: 0.7978 - val_loss: 0.4495 - val_binary_accuracy: 0.7986 - _timestamp: 1657801571.0000 - _runtime: 7.0000
# Epoch 6/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4420 - binary_accuracy: 0.8027 - val_loss: 0.4366 - val_binary_accuracy: 0.8029 - _timestamp: 1657801571.0000 - _runtime: 7.0000
# Epoch 7/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4308 - binary_accuracy: 0.8068 - val_loss: 0.4254 - val_binary_accuracy: 0.8067 - _timestamp: 1657801572.0000 - _runtime: 8.0000
# Epoch 8/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4212 - binary_accuracy: 0.8138 - val_loss: 0.4156 - val_binary_accuracy: 0.8229 - _timestamp: 1657801572.0000 - _runtime: 8.0000
# Epoch 9/300
# 77/77 [==============================] - 0s 4ms/step - loss: 0.4126 - binary_accuracy: 0.8236 - val_loss: 0.4067 - val_binary_accuracy: 0.8290 - _timestamp: 1657801572.0000 - _runtime: 8.0000
# Epoch 10/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4049 - binary_accuracy: 0.8306 - val_loss: 0.3993 - val_binary_accuracy: 0.8362 - _timestamp: 1657801572.0000 - _runtime: 8.0000
# Epoch 11/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3987 - binary_accuracy: 0.8327 - val_loss: 0.3941 - val_binary_accuracy: 0.8448 - _timestamp: 1657801573.0000 - _runtime: 9.0000
# Epoch 12/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3930 - binary_accuracy: 0.8353 - val_loss: 0.3870 - val_binary_accuracy: 0.8438 - _timestamp: 1657801573.0000 - _runtime: 9.0000
# Epoch 13/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3878 - binary_accuracy: 0.8372 - val_loss: 0.3821 - val_binary_accuracy: 0.8490 - _timestamp: 1657801573.0000 - _runtime: 9.0000
# Epoch 14/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3832 - binary_accuracy: 0.8398 - val_loss: 0.3779 - val_binary_accuracy: 0.8500 - _timestamp: 1657801573.0000 - _runtime: 9.0000
# Epoch 15/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3792 - binary_accuracy: 0.8404 - val_loss: 0.3738 - val_binary_accuracy: 0.8524 - _timestamp: 1657801573.0000 - _runtime: 9.0000
# Epoch 16/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3757 - binary_accuracy: 0.8404 - val_loss: 0.3704 - val_binary_accuracy: 0.8519 - _timestamp: 1657801574.0000 - _runtime: 10.0000
# Epoch 17/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3723 - binary_accuracy: 0.8445 - val_loss: 0.3670 - val_binary_accuracy: 0.8524 - _timestamp: 1657801574.0000 - _runtime: 10.0000
# Epoch 18/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3693 - binary_accuracy: 0.8462 - val_loss: 0.3645 - val_binary_accuracy: 0.8519 - _timestamp: 1657801574.0000 - _runtime: 10.0000
# Epoch 19/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3671 - binary_accuracy: 0.8474 - val_loss: 0.3626 - val_binary_accuracy: 0.8524 - _timestamp: 1657801575.0000 - _runtime: 11.0000
# Epoch 20/300
# 77/77 [==============================] - 0s 4ms/step - loss: 0.3648 - binary_accuracy: 0.8472 - val_loss: 0.3602 - val_binary_accuracy: 0.8543 - _timestamp: 1657801575.0000 - _runtime: 11.0000
# Epoch 21/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3630 - binary_accuracy: 0.8486 - val_loss: 0.3587 - val_binary_accuracy: 0.8533 - _timestamp: 1657801575.0000 - _runtime: 11.0000
# Epoch 22/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3613 - binary_accuracy: 0.8484 - val_loss: 0.3574 - val_binary_accuracy: 0.8538 - _timestamp: 1657801576.0000 - _runtime: 12.0000
# Epoch 23/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3598 - binary_accuracy: 0.8494 - val_loss: 0.3565 - val_binary_accuracy: 0.8538 - _timestamp: 1657801576.0000 - _runtime: 12.0000
# Epoch 24/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3587 - binary_accuracy: 0.8484 - val_loss: 0.3554 - val_binary_accuracy: 0.8538 - _timestamp: 1657801576.0000 - _runtime: 12.0000
# Epoch 25/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3576 - binary_accuracy: 0.8480 - val_loss: 0.3541 - val_binary_accuracy: 0.8543 - _timestamp: 1657801576.0000 - _runtime: 12.0000
# Epoch 26/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3566 - binary_accuracy: 0.8494 - val_loss: 0.3541 - val_binary_accuracy: 0.8543 - _timestamp: 1657801576.0000 - _runtime: 12.0000
# Epoch 27/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3556 - binary_accuracy: 0.8492 - val_loss: 0.3529 - val_binary_accuracy: 0.8548 - _timestamp: 1657801577.0000 - _runtime: 13.0000
# Epoch 28/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3547 - binary_accuracy: 0.8501 - val_loss: 0.3524 - val_binary_accuracy: 0.8548 - _timestamp: 1657801577.0000 - _runtime: 13.0000
# Epoch 29/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3540 - binary_accuracy: 0.8490 - val_loss: 0.3513 - val_binary_accuracy: 0.8543 - _timestamp: 1657801577.0000 - _runtime: 13.0000
# Epoch 30/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3532 - binary_accuracy: 0.8482 - val_loss: 0.3507 - val_binary_accuracy: 0.8595 - _timestamp: 1657801577.0000 - _runtime: 13.0000
# Epoch 31/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3524 - binary_accuracy: 0.8505 - val_loss: 0.3503 - val_binary_accuracy: 0.8567 - _timestamp: 1657801578.0000 - _runtime: 14.0000
# Epoch 32/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3517 - binary_accuracy: 0.8503 - val_loss: 0.3502 - val_binary_accuracy: 0.8552 - _timestamp: 1657801578.0000 - _runtime: 14.0000
# Epoch 33/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3514 - binary_accuracy: 0.8497 - val_loss: 0.3498 - val_binary_accuracy: 0.8548 - _timestamp: 1657801578.0000 - _runtime: 14.0000
# Epoch 34/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3507 - binary_accuracy: 0.8513 - val_loss: 0.3494 - val_binary_accuracy: 0.8557 - _timestamp: 1657801578.0000 - _runtime: 14.0000
# Epoch 35/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3501 - binary_accuracy: 0.8519 - val_loss: 0.3494 - val_binary_accuracy: 0.8567 - _timestamp: 1657801579.0000 - _runtime: 15.0000
# Epoch 36/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3495 - binary_accuracy: 0.8519 - val_loss: 0.3493 - val_binary_accuracy: 0.8557 - _timestamp: 1657801579.0000 - _runtime: 15.0000
# Epoch 37/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3492 - binary_accuracy: 0.8521 - val_loss: 0.3489 - val_binary_accuracy: 0.8586 - _timestamp: 1657801579.0000 - _runtime: 15.0000
# Epoch 38/300
# 77/77 [==============================] - 0s 2ms/step - loss: 0.3486 - binary_accuracy: 0.8527 - val_loss: 0.3492 - val_binary_accuracy: 0.8562 - _timestamp: 1657801579.0000 - _runtime: 15.0000
# Epoch 39/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3484 - binary_accuracy: 0.8531 - val_loss: 0.3485 - val_binary_accuracy: 0.8557 - _timestamp: 1657801579.0000 - _runtime: 15.0000
# Epoch 40/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3479 - binary_accuracy: 0.8542 - val_loss: 0.3490 - val_binary_accuracy: 0.8543 - _timestamp: 1657801580.0000 - _runtime: 16.0000
# Epoch 41/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3473 - binary_accuracy: 0.8527 - val_loss: 0.3499 - val_binary_accuracy: 0.8552 - _timestamp: 1657801580.0000 - _runtime: 16.0000
# Epoch 42/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3473 - binary_accuracy: 0.8548 - val_loss: 0.3480 - val_binary_accuracy: 0.8567 - _timestamp: 1657801580.0000 - _runtime: 16.0000
# Epoch 43/300
# 77/77 [==============================] - 0s 2ms/step - loss: 0.3468 - binary_accuracy: 0.8548 - val_loss: 0.3480 - val_binary_accuracy: 0.8557 - _timestamp: 1657801580.0000 - _runtime: 16.0000
# Epoch 44/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3463 - binary_accuracy: 0.8550 - val_loss: 0.3479 - val_binary_accuracy: 0.8543 - _timestamp: 1657801581.0000 - _runtime: 17.0000
# Epoch 45/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3460 - binary_accuracy: 0.8554 - val_loss: 0.3486 - val_binary_accuracy: 0.8552 - _timestamp: 1657801581.0000 - _runtime: 17.0000
# Epoch 46/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3458 - binary_accuracy: 0.8546 - val_loss: 0.3474 - val_binary_accuracy: 0.8562 - _timestamp: 1657801581.0000 - _runtime: 17.0000
# Epoch 47/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3452 - binary_accuracy: 0.8544 - val_loss: 0.3484 - val_binary_accuracy: 0.8562 - _timestamp: 1657801581.0000 - _runtime: 17.0000
# Epoch 48/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3450 - binary_accuracy: 0.8546 - val_loss: 0.3479 - val_binary_accuracy: 0.8562 - _timestamp: 1657801581.0000 - _runtime: 17.0000
# Epoch 49/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3439 - binary_accuracy: 0.8578 - val_loss: 0.3471 - val_binary_accuracy: 0.8562 - _timestamp: 1657801582.0000 - _runtime: 18.0000
# Epoch 50/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3442 - binary_accuracy: 0.8564 - val_loss: 0.3471 - val_binary_accuracy: 0.8552 - _timestamp: 1657801582.0000 - _runtime: 18.0000
# Epoch 51/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3439 - binary_accuracy: 0.8558 - val_loss: 0.3470 - val_binary_accuracy: 0.8571 - _timestamp: 1657801582.0000 - _runtime: 18.0000
# Epoch 52/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3434 - binary_accuracy: 0.8558 - val_loss: 0.3479 - val_binary_accuracy: 0.8571 - _timestamp: 1657801582.0000 - _runtime: 18.0000
# Epoch 53/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3433 - binary_accuracy: 0.8574 - val_loss: 0.3470 - val_binary_accuracy: 0.8571 - _timestamp: 1657801583.0000 - _runtime: 19.0000
# Epoch 54/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3427 - binary_accuracy: 0.8562 - val_loss: 0.3480 - val_binary_accuracy: 0.8562 - _timestamp: 1657801583.0000 - _runtime: 19.0000
# Epoch 55/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3426 - binary_accuracy: 0.8566 - val_loss: 0.3464 - val_binary_accuracy: 0.8548 - _timestamp: 1657801583.0000 - _runtime: 19.0000
# Epoch 56/300
# 77/77 [==============================] - 0s 2ms/step - loss: 0.3421 - binary_accuracy: 0.8550 - val_loss: 0.3471 - val_binary_accuracy: 0.8567 - _timestamp: 1657801583.0000 - _runtime: 19.0000
# Epoch 57/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3422 - binary_accuracy: 0.8574 - val_loss: 0.3468 - val_binary_accuracy: 0.8576 - _timestamp: 1657801584.0000 - _runtime: 20.0000
# Epoch 58/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3416 - binary_accuracy: 0.8566 - val_loss: 0.3465 - val_binary_accuracy: 0.8562 - _timestamp: 1657801584.0000 - _runtime: 20.0000
# Epoch 59/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3413 - binary_accuracy: 0.8587 - val_loss: 0.3463 - val_binary_accuracy: 0.8576 - _timestamp: 1657801584.0000 - _runtime: 20.0000
# Epoch 60/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3410 - binary_accuracy: 0.8574 - val_loss: 0.3458 - val_binary_accuracy: 0.8552 - _timestamp: 1657801584.0000 - _runtime: 20.0000
# Epoch 61/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3406 - binary_accuracy: 0.8568 - val_loss: 0.3459 - val_binary_accuracy: 0.8581 - _timestamp: 1657801584.0000 - _runtime: 20.0000
# Epoch 62/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3408 - binary_accuracy: 0.8570 - val_loss: 0.3461 - val_binary_accuracy: 0.8552 - _timestamp: 1657801585.0000 - _runtime: 21.0000
# Epoch 63/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3405 - binary_accuracy: 0.8558 - val_loss: 0.3471 - val_binary_accuracy: 0.8567 - _timestamp: 1657801585.0000 - _runtime: 21.0000
# Epoch 64/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3403 - binary_accuracy: 0.8578 - val_loss: 0.3456 - val_binary_accuracy: 0.8562 - _timestamp: 1657801585.0000 - _runtime: 21.0000
# Epoch 65/300
# 77/77 [==============================] - 0s 2ms/step - loss: 0.3400 - binary_accuracy: 0.8578 - val_loss: 0.3457 - val_binary_accuracy: 0.8557 - _timestamp: 1657801585.0000 - _runtime: 21.0000
# Epoch 66/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3397 - binary_accuracy: 0.8580 - val_loss: 0.3454 - val_binary_accuracy: 0.8557 - _timestamp: 1657801586.0000 - _runtime: 22.0000
# Epoch 67/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3392 - binary_accuracy: 0.8574 - val_loss: 0.3456 - val_binary_accuracy: 0.8576 - _timestamp: 1657801586.0000 - _runtime: 22.0000
# Epoch 68/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3391 - binary_accuracy: 0.8583 - val_loss: 0.3458 - val_binary_accuracy: 0.8581 - _timestamp: 1657801586.0000 - _runtime: 22.0000
# Epoch 69/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3391 - binary_accuracy: 0.8585 - val_loss: 0.3454 - val_binary_accuracy: 0.8552 - _timestamp: 1657801586.0000 - _runtime: 22.0000
# Epoch 70/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3388 - binary_accuracy: 0.8591 - val_loss: 0.3454 - val_binary_accuracy: 0.8548 - _timestamp: 1657801586.0000 - _runtime: 22.0000
# Epoch 71/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3384 - binary_accuracy: 0.8572 - val_loss: 0.3494 - val_binary_accuracy: 0.8576 - _timestamp: 1657801587.0000 - _runtime: 23.0000
# Epoch 72/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3386 - binary_accuracy: 0.8585 - val_loss: 0.3454 - val_binary_accuracy: 0.8571 - _timestamp: 1657801587.0000 - _runtime: 23.0000
# Epoch 73/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3382 - binary_accuracy: 0.8589 - val_loss: 0.3454 - val_binary_accuracy: 0.8562 - _timestamp: 1657801587.0000 - _runtime: 23.0000
# Epoch 74/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3379 - binary_accuracy: 0.8587 - val_loss: 0.3451 - val_binary_accuracy: 0.8571 - _timestamp: 1657801587.0000 - _runtime: 23.0000
# Epoch 75/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3377 - binary_accuracy: 0.8583 - val_loss: 0.3455 - val_binary_accuracy: 0.8567 - _timestamp: 1657801588.0000 - _runtime: 24.0000
# Epoch 76/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3375 - binary_accuracy: 0.8580 - val_loss: 0.3458 - val_binary_accuracy: 0.8548 - _timestamp: 1657801588.0000 - _runtime: 24.0000
# Epoch 77/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3371 - binary_accuracy: 0.8583 - val_loss: 0.3453 - val_binary_accuracy: 0.8562 - _timestamp: 1657801588.0000 - _runtime: 24.0000
# Epoch 78/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3370 - binary_accuracy: 0.8589 - val_loss: 0.3454 - val_binary_accuracy: 0.8571 - _timestamp: 1657801588.0000 - _runtime: 24.0000
# Epoch 79/300
# 77/77 [==============================] - 0s 4ms/step - loss: 0.3368 - binary_accuracy: 0.8589 - val_loss: 0.3461 - val_binary_accuracy: 0.8567 - _timestamp: 1657801589.0000 - _runtime: 25.0000
# Epoch 80/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3366 - binary_accuracy: 0.8597 - val_loss: 0.3457 - val_binary_accuracy: 0.8562 - _timestamp: 1657801589.0000 - _runtime: 25.0000
# Epoch 81/300
# 77/77 [==============================] - 0s 4ms/step - loss: 0.3363 - binary_accuracy: 0.8597 - val_loss: 0.3462 - val_binary_accuracy: 0.8567 - _timestamp: 1657801589.0000 - _runtime: 25.0000
# Epoch 82/300
# 77/77 [==============================] - 0s 4ms/step - loss: 0.3362 - binary_accuracy: 0.8605 - val_loss: 0.3448 - val_binary_accuracy: 0.8576 - _timestamp: 1657801590.0000 - _runtime: 26.0000
# Epoch 83/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3359 - binary_accuracy: 0.8587 - val_loss: 0.3447 - val_binary_accuracy: 0.8562 - _timestamp: 1657801590.0000 - _runtime: 26.0000
# Epoch 84/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3350 - binary_accuracy: 0.8589 - val_loss: 0.3488 - val_binary_accuracy: 0.8543 - _timestamp: 1657801590.0000 - _runtime: 26.0000
# Epoch 85/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3357 - binary_accuracy: 0.8593 - val_loss: 0.3457 - val_binary_accuracy: 0.8571 - _timestamp: 1657801590.0000 - _runtime: 26.0000
# Epoch 86/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3351 - binary_accuracy: 0.8605 - val_loss: 0.3444 - val_binary_accuracy: 0.8562 - _timestamp: 1657801590.0000 - _runtime: 26.0000
# Epoch 87/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3352 - binary_accuracy: 0.8589 - val_loss: 0.3440 - val_binary_accuracy: 0.8571 - _timestamp: 1657801591.0000 - _runtime: 27.0000
# Epoch 88/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3348 - binary_accuracy: 0.8597 - val_loss: 0.3443 - val_binary_accuracy: 0.8571 - _timestamp: 1657801591.0000 - _runtime: 27.0000
# Epoch 89/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3348 - binary_accuracy: 0.8597 - val_loss: 0.3441 - val_binary_accuracy: 0.8571 - _timestamp: 1657801591.0000 - _runtime: 27.0000
# Epoch 90/300
# 77/77 [==============================] - 0s 2ms/step - loss: 0.3344 - binary_accuracy: 0.8599 - val_loss: 0.3443 - val_binary_accuracy: 0.8571 - _timestamp: 1657801591.0000 - _runtime: 27.0000
# Epoch 91/300
# ...
# Epoch 212/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3135 - binary_accuracy: 0.8697 - val_loss: 0.3435 - val_binary_accuracy: 0.8567 - _timestamp: 1657801623.0000 - _runtime: 59.0000
# Epoch 213/300
# 77/77 [==============================] - 1s 8ms/step - loss: 0.3129 - binary_accuracy: 0.8701 - val_loss: 0.3465 - val_binary_accuracy: 0.8514 - _timestamp: 1657801624.0000 - _runtime: 60.0000
# Epoch 214/300
# 77/77 [==============================] - 1s 11ms/step - loss: 0.3128 - binary_accuracy: 0.8720 - val_loss: 0.3428 - val_binary_accuracy: 0.8581 - _timestamp: 1657801625.0000 - _runtime: 61.0000
# Epoch 215/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3132 - binary_accuracy: 0.8699 - val_loss: 0.3430 - val_binary_accuracy: 0.8581 - _timestamp: 1657801625.0000 - _runtime: 61.0000
# Epoch 216/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3129 - binary_accuracy: 0.8710 - val_loss: 0.3457 - val_binary_accuracy: 0.8548 - _timestamp: 1657801625.0000 - _runtime: 61.0000
# Epoch 217/300
# 77/77 [==============================] - 1s 8ms/step - loss: 0.3127 - binary_accuracy: 0.8705 - val_loss: 0.3447 - val_binary_accuracy: 0.8567 - _timestamp: 1657801626.0000 - _runtime: 62.0000
# Epoch 218/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3122 - binary_accuracy: 0.8716 - val_loss: 0.3472 - val_binary_accuracy: 0.8533 - _timestamp: 1657801626.0000 - _runtime: 62.0000
# Epoch 219/300
# 77/77 [==============================] - 1s 9ms/step - loss: 0.3122 - binary_accuracy: 0.8689 - val_loss: 0.3427 - val_binary_accuracy: 0.8567 - _timestamp: 1657801627.0000 - _runtime: 63.0000
# Epoch 220/300
# 77/77 [==============================] - 1s 8ms/step - loss: 0.3118 - binary_accuracy: 0.8697 - val_loss: 0.3441 - val_binary_accuracy: 0.8576 - _timestamp: 1657801628.0000 - _runtime: 64.0000
# Epoch 221/300
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3118 - binary_accuracy: 0.8697 - val_loss: 0.3429 - val_binary_accuracy: 0.8581 - _timestamp: 1657801628.0000 - _runtime: 64.0000
# Epoch 222/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3116 - binary_accuracy: 0.8691 - val_loss: 0.3431 - val_binary_accuracy: 0.8571 - _timestamp: 1657801629.0000 - _runtime: 65.0000
# Epoch 223/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3117 - binary_accuracy: 0.8703 - val_loss: 0.3433 - val_binary_accuracy: 0.8586 - _timestamp: 1657801629.0000 - _runtime: 65.0000
# Epoch 224/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3114 - binary_accuracy: 0.8701 - val_loss: 0.3441 - val_binary_accuracy: 0.8571 - _timestamp: 1657801629.0000 - _runtime: 65.0000
# Epoch 225/300
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3112 - binary_accuracy: 0.8705 - val_loss: 0.3446 - val_binary_accuracy: 0.8581 - _timestamp: 1657801630.0000 - _runtime: 66.0000
# Epoch 226/300
# 77/77 [==============================] - 1s 8ms/step - loss: 0.3109 - binary_accuracy: 0.8697 - val_loss: 0.3428 - val_binary_accuracy: 0.8605 - _timestamp: 1657801630.0000 - _runtime: 66.0000
# Epoch 227/300
# 77/77 [==============================] - 1s 10ms/step - loss: 0.3112 - binary_accuracy: 0.8705 - val_loss: 0.3448 - val_binary_accuracy: 0.8543 - _timestamp: 1657801631.0000 - _runtime: 67.0000
# Epoch 228/300
# 77/77 [==============================] - 1s 8ms/step - loss: 0.3111 - binary_accuracy: 0.8689 - val_loss: 0.3449 - val_binary_accuracy: 0.8590 - _timestamp: 1657801632.0000 - _runtime: 68.0000
# Epoch 229/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3108 - binary_accuracy: 0.8714 - val_loss: 0.3455 - val_binary_accuracy: 0.8548 - _timestamp: 1657801632.0000 - _runtime: 68.0000
# Epoch 230/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3111 - binary_accuracy: 0.8703 - val_loss: 0.3435 - val_binary_accuracy: 0.8614 - _timestamp: 1657801633.0000 - _runtime: 69.0000
# Epoch 231/300
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3101 - binary_accuracy: 0.8705 - val_loss: 0.3433 - val_binary_accuracy: 0.8576 - _timestamp: 1657801633.0000 - _runtime: 69.0000
# Epoch 232/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3104 - binary_accuracy: 0.8712 - val_loss: 0.3441 - val_binary_accuracy: 0.8567 - _timestamp: 1657801634.0000 - _runtime: 70.0000
# Epoch 233/300
# 77/77 [==============================] - 0s 4ms/step - loss: 0.3103 - binary_accuracy: 0.8693 - val_loss: 0.3441 - val_binary_accuracy: 0.8595 - _timestamp: 1657801634.0000 - _runtime: 70.0000
# Epoch 234/300
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3102 - binary_accuracy: 0.8720 - val_loss: 0.3447 - val_binary_accuracy: 0.8557 - _timestamp: 1657801634.0000 - _runtime: 70.0000
# Epoch 235/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3100 - binary_accuracy: 0.8718 - val_loss: 0.3456 - val_binary_accuracy: 0.8543 - _timestamp: 1657801635.0000 - _runtime: 71.0000
# Epoch 236/300
# 77/77 [==============================] - 1s 8ms/step - loss: 0.3097 - binary_accuracy: 0.8714 - val_loss: 0.3501 - val_binary_accuracy: 0.8490 - _timestamp: 1657801635.0000 - _runtime: 71.0000
# Epoch 237/300
# 77/77 [==============================] - 1s 8ms/step - loss: 0.3100 - binary_accuracy: 0.8716 - val_loss: 0.3452 - val_binary_accuracy: 0.8581 - _timestamp: 1657801636.0000 - _runtime: 72.0000
# Epoch 238/300
# 77/77 [==============================] - 1s 7ms/step - loss: 0.3095 - binary_accuracy: 0.8710 - val_loss: 0.3455 - val_binary_accuracy: 0.8571 - _timestamp: 1657801636.0000 - _runtime: 72.0000
# Epoch 239/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3092 - binary_accuracy: 0.8716 - val_loss: 0.3485 - val_binary_accuracy: 0.8476 - _timestamp: 1657801637.0000 - _runtime: 73.0000
# Epoch 240/300
# 77/77 [==============================] - 1s 7ms/step - loss: 0.3096 - binary_accuracy: 0.8710 - val_loss: 0.3466 - val_binary_accuracy: 0.8524 - _timestamp: 1657801637.0000 - _runtime: 73.0000
# Epoch 241/300
# 77/77 [==============================] - 1s 10ms/step - loss: 0.3090 - binary_accuracy: 0.8724 - val_loss: 0.3447 - val_binary_accuracy: 0.8614 - _timestamp: 1657801638.0000 - _runtime: 74.0000
# Epoch 242/300
# 77/77 [==============================] - 1s 8ms/step - loss: 0.3086 - binary_accuracy: 0.8730 - val_loss: 0.3495 - val_binary_accuracy: 0.8500 - _timestamp: 1657801639.0000 - _runtime: 75.0000
# Epoch 243/300
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3092 - binary_accuracy: 0.8718 - val_loss: 0.3468 - val_binary_accuracy: 0.8557 - _timestamp: 1657801639.0000 - _runtime: 75.0000
# Epoch 244/300
# 77/77 [==============================] - 1s 7ms/step - loss: 0.3092 - binary_accuracy: 0.8718 - val_loss: 0.3467 - val_binary_accuracy: 0.8571 - _timestamp: 1657801640.0000 - _runtime: 76.0000
# Epoch 245/300
# 77/77 [==============================] - 1s 8ms/step - loss: 0.3083 - binary_accuracy: 0.8720 - val_loss: 0.3461 - val_binary_accuracy: 0.8552 - _timestamp: 1657801641.0000 - _runtime: 77.0000
# Epoch 246/300
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3086 - binary_accuracy: 0.8718 - val_loss: 0.3451 - val_binary_accuracy: 0.8590 - _timestamp: 1657801641.0000 - _runtime: 77.0000
# Epoch 247/300
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3082 - binary_accuracy: 0.8720 - val_loss: 0.3453 - val_binary_accuracy: 0.8581 - _timestamp: 1657801642.0000 - _runtime: 78.0000
# Epoch 248/300
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3082 - binary_accuracy: 0.8726 - val_loss: 0.3496 - val_binary_accuracy: 0.8514 - _timestamp: 1657801642.0000 - _runtime: 78.0000
# Epoch 249/300
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3083 - binary_accuracy: 0.8718 - val_loss: 0.3468 - val_binary_accuracy: 0.8533 - _timestamp: 1657801642.0000 - _runtime: 78.0000
# Epoch 250/300
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3081 - binary_accuracy: 0.8716 - val_loss: 0.3457 - val_binary_accuracy: 0.8590 - _timestamp: 1657801643.0000 - _runtime: 79.0000
# Epoch 251/300
# 77/77 [==============================] - 1s 7ms/step - loss: 0.3082 - binary_accuracy: 0.8703 - val_loss: 0.3459 - val_binary_accuracy: 0.8600 - _timestamp: 1657801643.0000 - _runtime: 79.0000
# Epoch 252/300
# 77/77 [==============================] - 1s 11ms/step - loss: 0.3079 - binary_accuracy: 0.8716 - val_loss: 0.3506 - val_binary_accuracy: 0.8524 - _timestamp: 1657801644.0000 - _runtime: 80.0000
# Epoch 253/300
# 77/77 [==============================] - 0s 6ms/step - loss: 0.3075 - binary_accuracy: 0.8730 - val_loss: 0.3461 - val_binary_accuracy: 0.8581 - _timestamp: 1657801645.0000 - _runtime: 81.0000
# Epoch 254/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3073 - binary_accuracy: 0.8728 - val_loss: 0.3460 - val_binary_accuracy: 0.8605 - _timestamp: 1657801645.0000 - _runtime: 81.0000
# Epoch 255/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3075 - binary_accuracy: 0.8720 - val_loss: 0.3474 - val_binary_accuracy: 0.8567 - _timestamp: 1657801645.0000 - _runtime: 81.0000
# Epoch 256/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3072 - binary_accuracy: 0.8732 - val_loss: 0.3516 - val_binary_accuracy: 0.8476 - _timestamp: 1657801645.0000 - _runtime: 81.0000
# Epoch 257/300
# 77/77 [==============================] - 0s 4ms/step - loss: 0.3072 - binary_accuracy: 0.8724 - val_loss: 0.3477 - val_binary_accuracy: 0.8543 - _timestamp: 1657801646.0000 - _runtime: 82.0000
# Epoch 258/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3071 - binary_accuracy: 0.8697 - val_loss: 0.3474 - val_binary_accuracy: 0.8576 - _timestamp: 1657801646.0000 - _runtime: 82.0000
# Epoch 259/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3070 - binary_accuracy: 0.8726 - val_loss: 0.3465 - val_binary_accuracy: 0.8586 - _timestamp: 1657801646.0000 - _runtime: 82.0000
# Epoch 260/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3072 - binary_accuracy: 0.8720 - val_loss: 0.3471 - val_binary_accuracy: 0.8581 - _timestamp: 1657801646.0000 - _runtime: 82.0000
# Epoch 261/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3064 - binary_accuracy: 0.8720 - val_loss: 0.3478 - val_binary_accuracy: 0.8538 - _timestamp: 1657801647.0000 - _runtime: 83.0000
# Epoch 262/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3070 - binary_accuracy: 0.8724 - val_loss: 0.3484 - val_binary_accuracy: 0.8562 - _timestamp: 1657801647.0000 - _runtime: 83.0000
# Epoch 263/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3067 - binary_accuracy: 0.8722 - val_loss: 0.3485 - val_binary_accuracy: 0.8543 - _timestamp: 1657801647.0000 - _runtime: 83.0000
# Epoch 264/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3059 - binary_accuracy: 0.8728 - val_loss: 0.3467 - val_binary_accuracy: 0.8576 - _timestamp: 1657801647.0000 - _runtime: 83.0000
# Epoch 265/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3066 - binary_accuracy: 0.8716 - val_loss: 0.3482 - val_binary_accuracy: 0.8567 - _timestamp: 1657801648.0000 - _runtime: 84.0000
# Epoch 266/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3058 - binary_accuracy: 0.8746 - val_loss: 0.3511 - val_binary_accuracy: 0.8533 - _timestamp: 1657801648.0000 - _runtime: 84.0000
# Epoch 267/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3063 - binary_accuracy: 0.8738 - val_loss: 0.3494 - val_binary_accuracy: 0.8548 - _timestamp: 1657801648.0000 - _runtime: 84.0000
# Epoch 268/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3062 - binary_accuracy: 0.8716 - val_loss: 0.3496 - val_binary_accuracy: 0.8567 - _timestamp: 1657801648.0000 - _runtime: 84.0000
# Epoch 269/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3059 - binary_accuracy: 0.8738 - val_loss: 0.3497 - val_binary_accuracy: 0.8567 - _timestamp: 1657801649.0000 - _runtime: 85.0000
# Epoch 270/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3060 - binary_accuracy: 0.8726 - val_loss: 0.3487 - val_binary_accuracy: 0.8548 - _timestamp: 1657801649.0000 - _runtime: 85.0000
# Epoch 271/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3056 - binary_accuracy: 0.8724 - val_loss: 0.3492 - val_binary_accuracy: 0.8552 - _timestamp: 1657801649.0000 - _runtime: 85.0000
# Epoch 272/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3056 - binary_accuracy: 0.8744 - val_loss: 0.3501 - val_binary_accuracy: 0.8533 - _timestamp: 1657801649.0000 - _runtime: 85.0000
# Epoch 273/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3063 - binary_accuracy: 0.8726 - val_loss: 0.3505 - val_binary_accuracy: 0.8543 - _timestamp: 1657801650.0000 - _runtime: 86.0000
# Epoch 274/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3053 - binary_accuracy: 0.8720 - val_loss: 0.3508 - val_binary_accuracy: 0.8519 - _timestamp: 1657801650.0000 - _runtime: 86.0000
# Epoch 275/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3055 - binary_accuracy: 0.8734 - val_loss: 0.3521 - val_binary_accuracy: 0.8533 - _timestamp: 1657801650.0000 - _runtime: 86.0000
# Epoch 276/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3052 - binary_accuracy: 0.8744 - val_loss: 0.3483 - val_binary_accuracy: 0.8524 - _timestamp: 1657801650.0000 - _runtime: 86.0000
# Epoch 277/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3050 - binary_accuracy: 0.8736 - val_loss: 0.3489 - val_binary_accuracy: 0.8571 - _timestamp: 1657801651.0000 - _runtime: 87.0000
# Epoch 278/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3048 - binary_accuracy: 0.8742 - val_loss: 0.3485 - val_binary_accuracy: 0.8538 - _timestamp: 1657801651.0000 - _runtime: 87.0000
# Epoch 279/300
# 77/77 [==============================] - 0s 3ms/step - loss: 0.3048 - binary_accuracy: 0.8742 - val_loss: 0.3529 - val_binary_accuracy: 0.8510 - _timestamp: 1657801651.0000 - _runtime: 87.0000
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.025 MB of 0.025 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>binary_accuracy</td><td>▁▃▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇▇██████████</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_binary_accuracy</td><td>▁▄▇▇██▇█████▇███▇█████████████████▇▇▇██▇</td></tr><tr><td>val_loss</td><td>█▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>178</td></tr><tr><td>best_val_loss</td><td>0.34109</td></tr><tr><td>binary_accuracy</td><td>0.87423</td></tr><tr><td>epoch</td><td>278</td></tr><tr><td>loss</td><td>0.30481</td></tr><tr><td>val_binary_accuracy</td><td>0.85095</td></tr><tr><td>val_loss</td><td>0.35291</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">radiant-sweep-2</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1zcuptg0" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1zcuptg0</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220714_122604-1zcuptg0/logs</code>

# %%
run.finish()

# %% [markdown]
# ### 4.6 Export the best model

# %%
run = wandb.init(project=project_name,job_type="best_model")
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href="https://wandb.me/wandb-init" target="_blank">the W&B docs</a>.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220714_125940-1zcuptg0</code>
# Syncing run <strong><a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1zcuptg0" target="_blank">radiant-sweep-2</a></strong> to <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9mnf75ns" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9mnf75ns</a>

# %% [markdown]
# #### 4.6.1 Import the best wandb sweep

# %%
# restore the raw model file (Insert the wandb best sweep path)
best_model_path = "eec1509/churn_prediction_project_nn/q3dvclh5"
best_model = wandb.restore('model-best.h5', run_path=best_model_path)

# restore the model for tf.keras
model = tf.keras.models.load_model(best_model.name)

# %%
# execute the loss and accuracy using the test dataset
loss_, acc_ = model.evaluate(x=x_val,y=y_val, batch_size=64)
print('Test loss: %.3f - acc: %.3f' % (loss_, acc_))
# Out:
# 33/33 [==============================] - 0s 1ms/step - loss: 0.3406 - binary_accuracy: 0.8614
# Test loss: 0.341 - acc: 0.861

# %%
# source: https://github.com/wandb/awesome-dl-projects/blob/master/ml-tutorial/EMNIST_Dense_Classification.ipynb
import seaborn as sns
from sklearn.metrics import confusion_matrix

predictions = np.greater_equal(model.predict(x_val),0.5).astype(int)
cm = confusion_matrix(y_true = y_val, y_pred = predictions)

plt.figure(figsize=(6,6));
sns.heatmap(cm, annot=True)
plt.savefig('confusion_matrix.png', bbox_inches='tight')
plt.show()

# %%
wandb.log({"image_confusion_matrix": [wandb.Image('confusion_matrix.png')]})

# %% [markdown]
# #### 4.6.2 Export Encoders and Best Model

# %%
# types and names of the artifacts
artifact_type = "inference_artifact"
artifact_transform = "data_transform"
artifact_encoder = "target_encoder"
artifact_model = "model_export"

# %%
logger.info("Dumping the artifacts to disk")
# Out:
# 14-07-2022 12:40:40 Dumping the artifacts to disk

# %%
# Export Model artifact
artifact = wandb.Artifact(artifact_model,
                          type=artifact_type,
                          description="Neural Network Model for Classification Purpose"
                          )

logger.info("Logging model artifact")
model.save("path")
artifact.add_dir("path")
run.log_artifact(artifact)
# Out:
# 14-07-2022 12:59:56 Logging model artifact
# INFO:tensorflow:Assets written to: path/assets
# 14-07-2022 12:59:56 Assets written to: path/assets
# wandb: Adding directory to artifact (./path)... Done. 0.1s

# %%
# Export the pipe data transform using joblib
joblib.dump(pipe, artifact_transform)

# Pipe Data Transform
artifact = wandb.Artifact(artifact_transform,
                          type=artifact_type,
                          description="Pipeline for Data Transform"
                          )

logger.info("Logging Pipeline for Data Transform")
artifact.add_file(artifact_transform)
run.log_artifact(artifact)
# Out:
# 14-07-2022 12:41:11 Logging Pipeline for Data Transform

# %%
# Export the target encoder using joblib
joblib.dump(le, artifact_encoder)

# Target encoder artifact
artifact = wandb.Artifact(artifact_encoder,
                          type=artifact_type,
                          description="The encoder used to encode the target variable"
                          )

logger.info("Logging target enconder artifact")
artifact.add_file(artifact_encoder)
run.log_artifact(artifact)
# Out:
# 14-07-2022 12:41:42 Logging target enconder artifact

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.085 MB of 0.085 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">radiant-sweep-2</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1zcuptg0" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1zcuptg0</a><br/>Synced 5 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220714_125940-1zcuptg0/logs</code>

# %% [markdown]
# ## 5 - Testing

# %%
# initiate the wandb project
run = wandb.init(project="churn_prediction_project_nn",job_type="test")
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href="https://wandb.me/wandb-init" target="_blank">the W&B docs</a>.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/content/wandb/run-20220714_130008-1zcuptg0</code>
# Syncing run <strong><a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1zcuptg0" target="_blank">radiant-sweep-2</a></strong> to <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9mnf75ns" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9mnf75ns</a>

# %%
# global variables
# path of the artifact related to test dataset
artifact_test_path = "churn_prediction_project_nn/test.csv:latest"
# path of the pipeline for data transform
artifact_transform_path = "churn_prediction_project_nn/data_transform:latest"
# path of the model artifact
artifact_model_path = "model_export:latest"
# path of the target encoder artifact
artifact_encoder_path = "churn_prediction_project_nn/target_encoder:latest"

# %%
# configure logging
logging.basicConfig(level=logging.INFO,
                    format="%(asctime)s %(message)s",
                    datefmt='%d-%m-%Y %H:%M:%S')

# reference for a logging obj
logger = logging.getLogger()

# %% [markdown]
# ### 5.1 Download and Transform Test Data

# %%
logger.info("Downloading and reading test artifact")
test_data_path = run.use_artifact(artifact_test_path).file()
df_test = pd.read_csv(test_data_path)

# Extract the target from the features
logger.info("Extracting target from dataframe")
x_test_orig = df_test.copy()
y_test = x_test_orig.pop("Exited")
# Out:
# 14-07-2022 13:22:09 Downloading and reading test artifact
# 14-07-2022 13:22:10 Extracting target from dataframe

# %%
x_test_orig.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          790     Spain    Male   37       6       0.00              2
# 1          521    France    Male   35       6   96423.84              1
# 2          712    France  Female   37       1  106881.50              2
# 3          729     Spain  Female   38      10       0.00              2
# 4          695   Germany    Male   52       8  103023.26              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        119484.01
# 1          1               0         10488.44
# 2          0               0        169386.81
# 3          1               0        189727.12
# 4          1               1         22485.64

# %%
# Class for the data transform pipeline
class FeatureSelector(BaseEstimator, TransformerMixin):
    # Class Constructor
    def __init__(self, feature_names):
        self.feature_names = feature_names
        
    # Return self nothing to do here
    def fit(self, X, y=None):
        return self
    
    # Method that describes what tis custom transformer need to do
    def transform(self, X, y=None):
        return X[self.feature_names]
    
# Handling categorical features
class CategoricalTransformer(BaseEstimator, TransformerMixin):
    # Class constructor method that takes one boolean as argument
    def __init__(self, new_features=True, colnames=None):
        self.new_features = new_features
        self.colnames = colnames
        
    # Return self nothing else to do here
    def fit(self, X, y=None):
        return self
    
    def get_feature_names_out(self):
        return self.colnames.tolist()
    
    # Transformer method we wrote for this transformer
    def transform(self, X, y=None):
        df = pd.DataFrame(X, columns=self.colnames)
        
        # Remove white space in categorical features
        df = df.apply(lambda row: row.str.strip())
        
        # customize feature?
        # How can I identify what needs to be modified? EDA!!!!!!
        if self.new_features:
            
            # replace ? with unknown
            edit_cols = ['Geography', 'Gender']
            for col in edit_cols:
                df.loc[df[col].str.contains("\?"), col] = 'unknown'
        
        # update column names
        self.colnames = df.columns
        df = pd.DataFrame(X, columns=self.colnames)
        
        return df

# transform numerical features
class NumericalTransformer(BaseEstimator, TransformerMixin):
    # Class constructor method that takes a model parameter as its argument
    # model 0: minmax
    # model 1: standard
    # model 2: without scaler
    def __init__(self, model=0, colnames=None):
        self.model = model
        self.colnames = colnames
        self.scaler = None

    # Fit is used only to learn statistical about Scalers
    def fit(self, X, y=None):
        df = pd.DataFrame(X, columns=self.colnames)
        
        # minmax
        if self.model == 0:
            self.scaler = MinMaxScaler()
            self.scaler.fit(df)
        # standard scaler
        elif self.model == 1:
            self.scaler = StandardScaler()
            self.scaler.fit(df)
        return self

    # return columns names after transformation
    def get_feature_names_out(self):
        return self.colnames

    # Transformer method we wrote for this transformer
    # Use fitted scalers
    def transform(self, X, y=None):
        df = pd.DataFrame(X, columns=self.colnames)
        
        # update columns name
        self.colnames = df.columns.tolist()

        # minmax
        if self.model == 0:
            # transform data
            df = self.scaler.transform(df)
        elif self.model == 1:
            # transform data
            df = self.scaler.transform(df)
        else:
            df = df.values

        return df

# %%
# Download the pipeline for dada transform 
logger.info("Downloading the dada transform pipeline")
data_transform_path = run.use_artifact(artifact_transform_path).file()
pipe = joblib.load(data_transform_path)

# Transform test data
x_test = pipe.transform(x_test_orig)
# Out:
# 14-07-2022 12:46:54 Downloading the dada transform pipeline

# %%
x_test.shape
# Out:
# (3000, 11)

# %%
x_test
# Out:
# array([[ 0.        ,  1.        ,  1.        , ...,  0.64362459,
#          0.95944516,  0.34273475],
#        [ 0.        ,  0.        ,  1.        , ...,  0.64362459,
#         -1.04226906, -1.54920337],
#        [ 0.        ,  0.        ,  0.        , ..., -1.55370075,
#         -1.04226906,  1.20894435],
#        ...,
#        [ 1.        ,  0.        ,  1.        , ..., -1.55370075,
#         -1.04226906,  0.46514135],
#        [ 1.        ,  0.        ,  0.        , ...,  0.64362459,
#         -1.04226906, -1.40281106],
#        [ 0.        ,  0.        ,  1.        , ...,  0.64362459,
#         -1.04226906,  0.99520047]])

# %%
y_test_orig
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2995    0
# 2996    0
# 2997    0
# 2998    1
# 2999    0
# Name: Exited, Length: 3000, dtype: int64

# %% [markdown]
# ### 5.2 Encoding Target Variable

# %%
# Download the target variable encoder
logger.info("Extracting the encoding of the target variable")
encoder_path = run.use_artifact(artifact_encoder_path).file()
le = joblib.load(encoder_path)
# Target encoding
y_test_encoded = le.inverse_transform(y_test)
# Out:
# 14-07-2022 13:22:35 Extracting the encoding of the target variable

# %%
y_test_encoded
# Out:
# array(['Contiuned', 'Contiuned', 'Contiuned', ..., 'Contiuned', 'Exited',
#        'Contiuned'], dtype='<U9')

# %% [markdown]
# ### 5.3 Download the Best Model and Test

# %%
# Download inference artifact
logger.info("Downloading and load the exported model")
# use the latest version of the model
model_at = run.use_artifact(artifact_model_path)
# download the directory in which the model is saved
model_dir= model_at.download()
print("model: ", model_dir)
model = keras.models.load_model(model_dir)
# Out:
# 14-07-2022 13:00:56 Downloading and load the exported model
# model:  ./artifacts/model_export:v1

# %%
# predict
logger.info("Infering")
predict = model.predict(x_test)
# Out:
# 14-07-2022 13:01:25 Infering

# %%
predict
# Out:
# array([[0.0202989 ],
#        [0.06348157],
#        [0.14023054],
#        ...,
#        [0.33095452],
#        [0.11221516],
#        [0.01008829]], dtype=float32)

# %%
predict_rounded = np.rint(predict)

# %%
predict_rounded
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
# execute the loss and accuracy using the test dataset
loss_, acc_ = model.evaluate(x=x_test,y=y_test, batch_size=64)
print('Test loss: %.3f - acc: %.3f' % (loss_, acc_))
# Out:
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3271 - binary_accuracy: 0.8667
# Test loss: 0.327 - acc: 0.867

# %%
# Evaluation Metrics
logger.info("Test Evaluation metrics")
fbeta = fbeta_score(y_test, predict_rounded, beta=1, zero_division=1)
precision = precision_score(y_test, predict_rounded, zero_division=1)
recall = recall_score(y_test, predict_rounded, zero_division=1)
acc = accuracy_score(y_test, predict_rounded)

logger.info("Test Accuracy: {}".format(acc))
logger.info("Test Precision: {}".format(precision))
logger.info("Test Recall: {}".format(recall))
logger.info("Test F1: {}".format(fbeta))

run.summary["Acc"] = acc
run.summary["Precision"] = precision
run.summary["Recall"] = recall
run.summary["F1"] = fbeta
# Out:
# 14-07-2022 13:27:02 Test Evaluation metrics
# 14-07-2022 13:27:02 Test Accuracy: 0.8666666666666667
# 14-07-2022 13:27:02 Test Precision: 0.790633608815427
# 14-07-2022 13:27:02 Test Recall: 0.469721767594108
# 14-07-2022 13:27:02 Test F1: 0.5893223819301847

# %%
# Compare the accuracy, precision, recall with previous ones
print(classification_report(y_test,predict_rounded))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      2389
#            1       0.79      0.47      0.59       611
#
#     accuracy                           0.87      3000
#    macro avg       0.83      0.72      0.75      3000
# weighted avg       0.86      0.87      0.85      3000

# %%
fig_confusion_matrix, ax = plt.subplots(1,1,figsize=(7,4))
ConfusionMatrixDisplay(confusion_matrix(predict_rounded,y_test,labels=[1,0]),
                       display_labels=["1","0"]).plot(values_format=".0f",ax=ax)

ax.set_xlabel("True Label")
ax.set_ylabel("Predicted Label")
plt.show()

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.86667</td></tr><tr><td>F1</td><td>0.58932</td></tr><tr><td>Precision</td><td>0.79063</td></tr><tr><td>Recall</td><td>0.46972</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">radiant-sweep-2</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1zcuptg0" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1zcuptg0</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220714_130008-1zcuptg0/logs</code>
