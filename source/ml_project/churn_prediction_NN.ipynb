# %% [markdown]
# # Customer Churn Prediction
# Machine Learning Project - Decison Tree Classification
#
# Authors:
# * José Marcos Leal Barbosa Filho
# * Lucas Ismael Campos Medeiros
#
# Institution: Universidade Federal do Rio Grande do Norte - Brazil.

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# It is a **customer churn** modeling dataset containing 10.000 rows (each representing an unique customer) with 14 columns: 13 general features and one target feature (**Exited**). The data is composed of both numerical and categorical features:
#
# **Numeric Features:**
#
#     RowNumber: The sequence number of the rows.
#     CustomerId: A unique ID of the customer.
#     CreditScore: The credit score of the customer,
#     Age: The age of the customer,
#     Tenure: The number of months the client has been with the firm.
#     Balance: Balance remaining in the customer account,
#     NumOfProducts: The number of products purchased by the customer.
#     EstimatedSalary: The estimated salary of the customer.
#
# **Categorical Features:**
#
#     Surname: The surname of the customer.
#     Geography: The country of the customer.
#     Gender: M/F
#     HasCrCard: Whether the customer has a credit card or not.
#     IsActiveMember: Whether the customer is active or not.
#
# **The target column:**
#
#     Exited — Whether the customer churned or not.
#
# The dataset can be seen and downloaded [here](https://www.kaggle.com/datasets/aakash50897/churn-modellingcsv?resource=download).

# %% [markdown]
# ## Load Libraries

# %%
# %%capture
# !pip install wandb
#!pip install wandb==0.10.17
# !pip install pytest pytest-sugar
# !pip install pandas-profiling==3.1.0

# %%
import wandb
import logging
import tempfile
import os
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas_profiling import ProfileReport
from sklearn.model_selection import train_test_split
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.impute import SimpleImputer
from sklearn.metrics import fbeta_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

import tensorflow as tf
from tensorflow import keras
from keras.callbacks import EarlyStopping
import h5py
import time
import datetime
import pytz
import IPython

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ## Login to wandb

# %%
# !wandb login --relogin
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## 1.Extract, Transform and Load (ETL)

# %% [markdown]
# ### 1.1.Fetch Data

# %%
# columns used
columns = ['RowNumber', 'CustomerId', 'Surname', 'CreditScore',
           'Geography', 'Gender', 'Age', 'Tenure', 
           'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
           'EstimatedSalary', 'Exited']
# importing the dataset
churndf = pd.read_csv("https://github.com/x4nth055/pythoncode-tutorials/raw/master/machine-learning/customer-churn-detection/Churn_Modelling.csv",
                      header=None,
                      names=columns)
churndf.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Geography  Gender  Age  \
# 0  RowNumber  CustomerId   Surname  CreditScore  Geography  Gender  Age
# 1          1    15634602  Hargrave          619     France  Female   42
# 2          2    15647311      Hill          608      Spain  Female   41
# 3          3    15619304      Onio          502     France  Female   42
# 4          4    15701354      Boni          699     France  Female   39
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0  Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember
# 1       2         0              1          1               1
# 2       1  83807.86              1          0               1
# 3       8  159660.8              3          1               0
# 4       1         0              2          0               0
#
#    EstimatedSalary  Exited
# 0  EstimatedSalary  Exited
# 1        101348.88       1
# 2        112542.58       0
# 3        113931.57       1
# 4         93826.63       0

# %% [markdown]
# * It was chosen to remove the following columns:
#
#   * **RowNumber:** Indicates only the sequence number of the lines;
#   * **CustomerId:** High cardinality column with 10,000 unique IDs;
#   * **Surname:** Column with high cardinality, showing the last names of each consumer.

# %%
# removing unecessary columns and reseting indexes
churndf = churndf.drop([0,])
churndf.drop(columns=['RowNumber', 'CustomerId', 'Surname'], inplace=True)
churndf.reset_index(drop=True,inplace=True)
churndf.head()
# Out:
#   CreditScore Geography  Gender Age Tenure    Balance NumOfProducts HasCrCard  \
# 0         619    France  Female  42      2          0             1         1
# 1         608     Spain  Female  41      1   83807.86             1         0
# 2         502    France  Female  42      8   159660.8             3         1
# 3         699    France  Female  39      1          0             2         0
# 4         850     Spain  Female  43      2  125510.82             1         1
#
#   IsActiveMember EstimatedSalary Exited
# 0              1       101348.88      1
# 1              1       112542.58      0
# 2              0       113931.57      1
# 3              0        93826.63      0
# 4              1         79084.1      0

# %%
# saving to csv
churndf.to_csv("raw_data.csv", index=False)

# %%
# Saving artifact to wandb
# !wandb artifact put \
       --name churn_prediction_project_nn/raw_data.csv \
       --type raw_data \
       --description "Customer Churn NN" raw_data.csv
# Out:
# wandb: Uploading file raw_data.csv to: "eec1509/churn_prediction_project_nn/raw_data.csv:latest" (raw_data)
# wandb: Currently logged in as: eec1509 (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.17
# wandb: Syncing run stilted-oath-1
# wandb: ⭐️ View project at https://wandb.ai/eec1509/churn_prediction_project_nn
# wandb: 🚀 View run at https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1u5nsujn
# wandb: Run data is saved locally in /content/wandb/run-20220712_153322-1u5nsujn
# wandb: Run `wandb offline` to turn off syncing.
#
# Artifact uploaded, use this artifact in a run by adding:
#
#     artifact = run.use_artifact("eec1509/churn_prediction_project_nn/raw_data.csv:latest")
#
#
# wandb: Waiting for W&B process to finish, PID 774
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /content/wandb/run-20220712_153322-1u5nsujn/logs/debug.log
# wandb: Find internal logs for this run at: /content/wandb/run-20220712_153322-1u5nsujn/logs/debug-internal.log
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced stilted-oath-1: https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1u5nsujn

# %% [markdown]
# ----------------

# %% [markdown]
# ### 1.2.Exploratory Data Analysis (EDA)

# %%
# save_code tracking all changes of the notebook and sync with Wandb
run = wandb.init(project="churn_prediction_project_nn", save_code=True)
# Out:
# wandb: Currently logged in as: eec1509 (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.17<br/>
#                 Syncing run <strong style="color:#cdcd00">lunar-sound-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn</a><br/>
#                 Run page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3i9kcuyv" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3i9kcuyv</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20220712_153331-3i9kcuyv</code><br/><br/>

# %%
# download the latest version of artifact raw_data.csv
artifact = run.use_artifact("churn_prediction_project_nn/raw_data.csv:latest")

# create a dataframe from the artifact
df = pd.read_csv(artifact.file())

# %% [markdown]
# #### 1.2.1 Pandas Profiling

# %%
ProfileReport(df, title= "Pandas Profiling Report", explorative=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 812<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20220712_153331-3i9kcuyv/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20220712_153331-3i9kcuyv/logs/debug-internal.log</code>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">lunar-sound-2</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3i9kcuyv" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3i9kcuyv</a><br/>

# %% [markdown]
# --------------------------

# %% [markdown]
# ### 1.3.Preprocessing

# %%
input_artifact="churn_prediction_project_nn/raw_data.csv:latest"
artifact_name="preprocessed_data.csv"
artifact_type="clean_data"
artifact_description="Data after preprocessing"

# %%
# create a new job_type
run = wandb.init(project="churn_prediction_project_nn", job_type="process_data")
# Out:
# wandb: wandb version 0.12.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.17<br/>
#                 Syncing run <strong style="color:#cdcd00">efficient-bird-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn</a><br/>
#                 Run page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3h5od3df" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3h5od3df</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20220712_153354-3h5od3df</code><br/><br/>

# %%
# download the latest version of artifact raw_data.csv
artifact=run.use_artifact(input_artifact)

# create a dataframe from the artifact
df = pd.read_csv(artifact.file())

# %%
# delete duplicated rows
df.drop_duplicates(inplace=True)

# generate a "clean data file"
df.to_csv(artifact_name, index=False)

# %%
# Create a new artifact and configure with the necessary arguments
artifact = wandb.Artifact(name=artifact_name,
                         type=artifact_type,
                         description=artifact_description)
artifact.add_file(artifact_name)
# Out:
# <ManifestEntry digest: 2VNPzyBON65Yp9cxPORlnA==>

# %%
run.log_artifact(artifact)

# %%
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 873<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.45MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.00112617407…
# Find user logs for this run at: <code>/content/wandb/run-20220712_153354-3h5od3df/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20220712_153354-3h5od3df/logs/debug-internal.log</code>
# Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">efficient-bird-3</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3h5od3df" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3h5od3df</a><br/>

# %% [markdown]
# ----------------------------

# %% [markdown]
# ## 2.Data Check

# %%
# %%file test_data.py
import pytest
import wandb
import pandas as pd

# This is global so all tests are collected under the same run
run = wandb.init(project="churn_prediction_project_nn", job_type="data_checks")

@pytest.fixture(scope="session")
def data():

    local_path = run.use_artifact("churn_prediction_project_nn/preprocessed_data.csv:latest").file()
    df = pd.read_csv(local_path)

    return df

def test_data_length(data):
    """
    We test that we have enough data to continue
    """
    assert len(data) > 1000


def test_number_of_columns(data):
    """
    We test that we have enough data to continue
    """
    assert data.shape[1] == 11

def test_column_presence_and_type(data):

    required_columns = {
        #"CustomerId": pd.api.types.is_int64_dtype,
        #"Surname": pd.api.types.is_object_dtype,
        "CreditScore": pd.api.types.is_int64_dtype,
        "Geography": pd.api.types.is_object_dtype,
        "Gender": pd.api.types.is_object_dtype,
        "Age": pd.api.types.is_int64_dtype,
        "Tenure": pd.api.types.is_int64_dtype,
        "Balance": pd.api.types.is_float_dtype,
        "NumOfProducts": pd.api.types.is_int64_dtype,
        "HasCrCard": pd.api.types.is_int64_dtype,
        "IsActiveMember": pd.api.types.is_int64_dtype,
        "EstimatedSalary": pd.api.types.is_float_dtype,  
        "Exited": pd.api.types.is_int64_dtype
    }

    # Check column presence
    assert set(data.columns.values).issuperset(set(required_columns.keys()))

    for col_name, format_verification_funct in required_columns.items():

        assert format_verification_funct(data[col_name]), f"Column {col_name} failed test {format_verification_funct}"


def test_class_names(data):

    # Check that only the known classes are present
    known_classes = [
        0,
        1
    ]

    assert data["Exited"].isin(known_classes).all()


def test_column_ranges(data):

    ranges = {
        "CreditScore": (0, 1000),
        "Age": (0,100),
        "Tenure": (0,10),
        "Balance": (0, 1.484705e+06),
        "NumOfProducts": (1,4),
        "HasCrCard": (0,1),
        "IsActiveMember": (0,1),
        "EstimatedSalary": (0, 1.484705e+06),
        "Exited": (0, 1)
    }

    for col_name, (minimum, maximum) in ranges.items():

        assert data[col_name].dropna().between(minimum, maximum).all(), (
            f"Column {col_name} failed the test. Should be between {minimum} and {maximum}, "
            f"instead min={data[col_name].min()} and max={data[col_name].max()}"
        )
# Out:
# Overwriting test_data.py

# %%
# !pytest . -vv
# Out:
# Test session starts (platform: linux, Python 3.7.13, pytest 3.6.4, pytest-sugar 0.9.5)
# cachedir: .pytest_cache
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1, sugar-0.9.5
#
#  test_data.py::test_data_length ✓                                 20% ██
#  test_data.py::test_number_of_columns ✓                           40% ████
#  test_data.py::test_column_presence_and_type ✓                    60% ██████
#  test_data.py::test_class_names ✓                                 80% ████████
#  test_data.py::test_column_ranges ✓                              100% ██████████
#
# Results (5.31s):
#        5 passed

# %%
run.finish()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-7da56333b3d5> in <module>()
# ----> 1 run.finish()
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py in finish(self, exit_code)
#    1056         logger.info("finishing run %s", self.path)
#    1057         for hook in self._teardown_hooks:
# -> 1058             hook()
#    1059         self._atexit_cleanup(exit_code=exit_code)
#    1060         if self._wl and len(self._wl._global_run_stack) > 0:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py in _jupyter_teardown(self)
#     257             if "_pause_backend" in hook.__name__:
#     258                 ipython.events.unregister("post_run_cell", hook)
# --> 259         ipython.display_pub.publish = ipython.display_pub._orig_publish
#     260         del ipython.display_pub._orig_publish
#     261
#
# AttributeError: 'ZMQDisplayPublisher' object has no attribute '_orig_publish'

# %% [markdown]
# ----------------------------------------

# %% [markdown]
# ## 3.Data Segregation

# %%
# global variables

# ratio - 70% train / 30% test
test_size = 0.30

# seed used to reproduce purposes
seed = 42

# reference (column) to stratify the data
stratify = "Exited"

# name of the input artifact
artifact_input_name = "churn_prediction_project_nn/preprocessed_data.csv:latest"

# type of the artifact
artifact_type = "segregated_data"

# %%
# configure logging 
logging.basicConfig(level=logging.INFO,
                   format="%(asctime)s %(message)s",
                   datefmt='%d-%m-%Y %H:%M:%S')

# reference for a logging object
logger = logging.getLogger()

# init wandb project
run = wandb.init(project="churn_prediction_project_nn", job_type="split_data")

logger.info("Downloading and reading artifact")
artifact=run.use_artifact(artifact_input_name)
artifact_path=artifact.file()
df = pd.read_csv(artifact_path)
# Out:
# Finishing last run (ID:3jxkbmzg) before initializing another...
# <br/>Waiting for W&B process to finish, PID 1080<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.44MB of 0.44MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20220712_154334-3jxkbmzg/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20220712_154334-3jxkbmzg/logs/debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">wise-pond-6</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3jxkbmzg" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3jxkbmzg</a><br/>
# ...Successfully finished last run (ID:3jxkbmzg). Initializing new run:<br/><br/>
# wandb: wandb version 0.12.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.17<br/>
#                 Syncing run <strong style="color:#cdcd00">ethereal-dragon-7</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn</a><br/>
#                 Run page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3ippeg6e" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3ippeg6e</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20220712_154458-3ippeg6e</code><br/><br/>
# 12-07-2022 15:45:05 Downloading and reading artifact

# %%
# Split in train/test
train, test = train_test_split(df,test_size=test_size,
                                  random_state=seed,
                                  stratify=df[stratify])

# %%
# Data Encoding
# seperate data as idepedent variables and dependent variable
x_train = train.iloc[:,0:-1]
y_train = train.iloc[:,-1:]
x_test = test.iloc[:,0:-1]
y_test = test.iloc[:,-1:]

# %%
# Numeric data transform
sc = StandardScaler()
for name in x_train.select_dtypes(exclude = "object").columns.to_list():
    # fit using x_train
    sc.fit(x_train[name].values.reshape(-1,1))

    # transform train and validation
    x_train[name] = sc.transform(x_train[name].values.reshape(-1,1))
    x_test[name] = sc.transform(x_test[name].values.reshape(-1,1))

# %%
# Categorical data transform 
for name in x_train.select_dtypes("object").columns.to_list():
    onehot = OneHotEncoder(sparse=False,drop="first")
    # fit using x_train
    onehot.fit(x_train[name].values.reshape(-1,1))

    # transform train and validation
    x_train[onehot.get_feature_names_out()] = onehot.transform(x_train[name].values.reshape(-1,1))
    x_test[onehot.get_feature_names_out()] = onehot.transform(x_test[name].values.reshape(-1,1))

# %%
cols = x_train.select_dtypes("object").columns.to_list()

# %%
x_train.drop(labels=cols,axis=1,inplace=True)
x_test.drop(labels=cols,axis=1,inplace=True)

# %%
train_encoded = pd.concat([x_train, y_train], axis = 1)
test_encoded = pd.concat([x_test, y_test], axis = 1)

# %%
splits={}
splits["train"], splits["test"] = [train_encoded, test_encoded]

# %%
# Save artifacts
with tempfile.TemporaryDirectory() as tmp_dir:
    
    for split, df in splits.items():
        
        # Make the artifact name from the name of the split plus the provided root
        artifact_name = f"{split}.csv"
        
        # Get the path on disk within the temp directory
        temp_path = os.path.join(tmp_dir,artifact_name)
        
        logger.info(f"Uploading the {split} dataset to {artifact_name}")
        
        # Save then upload to W&B
        df.to_csv(temp_path,index=False)
        
        artifact = wandb.Artifact(name=artifact_name,
                                 type=artifact_type,
                                 description=f"{split} split of dataset {artifact_input_name}")
        artifact.add_file(temp_path)
        
        logger.info("Logging artifact")
        run.log_artifact(artifact)
        
        #artifact.wait()
# Out:
# 12-07-2022 15:45:06 Uploading the train dataset to train.csv
# 12-07-2022 15:45:06 Logging artifact
# 12-07-2022 15:45:06 Uploading the test dataset to test.csv
# 12-07-2022 15:45:06 Logging artifact

# %%
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 1141<br/>Program ended successfully.
# VBox(children=(Label(value=' 1.13MB of 1.62MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.70013473549…
# Find user logs for this run at: <code>/content/wandb/run-20220712_154458-3ippeg6e/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20220712_154458-3ippeg6e/logs/debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ethereal-dragon-7</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3ippeg6e" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/3ippeg6e</a><br/>

# %% [markdown]
# ------------------------

# %% [markdown]
# ## 4.Trainning

# %% [markdown]
# ### 4.1.Holdout Configuration

# %%
# global variables

# ratio used to split train and validation data
val_size = 0.30

# seed used to reproduce purposes
seed = 42

# reference (column) to stratify the data
stratify = "Exited"

# name of the input artifact
artifact_input_name = "churn_prediction_project_nn/train.csv:latest"

#entity
entity_name = "eec1509"

# project name
project_name = "churn_prediction_project_nn"

# type of the artifact
artifact_type = "Train"

# %%
# configure logging
logging.basicConfig(level=logging.INFO,
                    format="%(asctime)s %(message)s",
                    datefmt='%d-%m-%Y %H:%M:%S')

# reference for a logging obj
logger = logging.getLogger()

# initiate the wandb project
run = wandb.init(project="churn_prediction_project_nn", job_type="train")

logger.info("Downloading and reading train artifact")
local_path = run.use_artifact(artifact_input_name).file()
df_train = pd.read_csv(local_path)

# Spliting train.csv into train and validation dataset
logger.info("Spliting data into train/val")
# split-out train/validation and test dataset
x_train, x_val, y_train, y_val = train_test_split(df_train.drop(labels=stratify,axis=1),
                                                  df_train[stratify],
                                                  test_size=val_size,
                                                  random_state=seed,
                                                  shuffle=True,
                                                  stratify=df_train[stratify])
# Out:
# Finishing last run (ID:u1fg480l) before initializing another...
# <br/>Waiting for W&B process to finish, PID 22334<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20220712_174614-u1fg480l/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20220712_174614-u1fg480l/logs/debug-internal.log</code>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">olive-salad-30</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/u1fg480l" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/u1fg480l</a><br/>
# ...Successfully finished last run (ID:u1fg480l). Initializing new run:<br/><br/>
# wandb: wandb version 0.12.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.17<br/>
#                 Syncing run <strong style="color:#cdcd00">amber-glitter-31</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn</a><br/>
#                 Run page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/z200b2wn" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/z200b2wn</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20220712_174742-z200b2wn</code><br/><br/>
# 12-07-2022 17:47:49 Downloading and reading train artifact
# 12-07-2022 17:47:50 Spliting data into train/val

# %%
logger.info("x train: {}".format(x_train.shape))
logger.info("y train: {}".format(y_train.shape))
logger.info("x val: {}".format(x_val.shape))
logger.info("y val: {}".format(y_val.shape))
# Out:
# 12-07-2022 17:47:50 x train: (4900, 11)
# 12-07-2022 17:47:50 y train: (4900,)
# 12-07-2022 17:47:50 x val: (2100, 11)
# 12-07-2022 17:47:50 y val: (2100,)

# %% [markdown]
# ### 4.2.Data Preparation

# %% [markdown]
# #### 4.2.1.Outlier Removal

# %%
logger.info("Outlier Removal")
# temporary variable
x = x_train.select_dtypes("float64").copy()

# identify outlier in the dataset
lof = LocalOutlierFactor()
outlier = lof.fit_predict(x)
mask = outlier != -1
# Out:
# 12-07-2022 17:47:51 Outlier Removal

# %%
logger.info("x_train shape [original]: {}".format(x_train.shape))
logger.info("x_train shape [outlier removal]: {}".format(x_train.loc[mask,:].shape))
# Out:
# 12-07-2022 17:47:52 x_train shape [original]: (4900, 11)
# 12-07-2022 17:47:52 x_train shape [outlier removal]: (4898, 11)

# %%
logger.info("y_train shape [original]: {}".format(y_train.shape))
logger.info("y_train shape [outlier removal]: {}".format(y_train.loc[mask].shape))
# Out:
# 12-07-2022 17:47:52 y_train shape [original]: (4900,)
# 12-07-2022 17:47:52 y_train shape [outlier removal]: (4898,)

# %%
# AVOID data leakage and you should not do this procedure in the preprocessing stage
# Note that we did not perform this procedure in the validation set
x_train = x_train.loc[mask,:].copy()
y_train = y_train[mask].copy()

# %% [markdown]
# #### 4.2.2.Target Variable Encoding

# %% [markdown]
# In this case, the target variable is already encoded, but let's create an encoder to transform the numeric variable into categorical.

# %%
logger.info("Encoding a Target Variable")

# define a categorical encoding for target variable
le = LabelEncoder()
le.fit(["Contiuned", "Exited"])
teste = le.inverse_transform(y_train)
# Out:
# 12-07-2022 17:47:52 Encoding a Target Variable

# %% [markdown]
# ### 4.3 Base Model

# %%
class MyCustomCallback(tf.keras.callbacks.Callback):

  def on_train_begin(self, batch, logs=None):
    self.begins = time.time()
    print('Training: begins at {}'.format(datetime.datetime.now(pytz.timezone('America/Fortaleza')).strftime("%a, %d %b %Y %H:%M:%S")))

  def on_train_end(self, logs=None):
    print('Training: ends at {}'.format(datetime.datetime.now(pytz.timezone('America/Fortaleza')).strftime("%a, %d %b %Y %H:%M:%S")))
    print('Duration: {:.2f} seconds'.format(time.time() - self.begins))

# %%
N, D = x_train.shape

# %%
# Instantiate a simple classification model
model = tf.keras.Sequential([
  tf.keras.layers.Dense(13, kernel_initializer = 'uniform', activation='relu', input_dim = D),
  tf.keras.layers.Dense(12, kernel_initializer = 'uniform', activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# Instantiate a logistic loss function that expects integer targets.
loss = tf.keras.losses.BinaryCrossentropy()

# Instantiate an accuracy metric.
accuracy = tf.keras.metrics.BinaryAccuracy()

# Instantiate an optimizer.
#optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.02)

# configure the optimizer, loss, and metrics to monitor.
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[accuracy])

# training 
history = model.fit(x=x_train,
                    y=y_train,
                    batch_size=64,
                    epochs=5,
                    validation_data=(x_val,y_val),
                    callbacks=[MyCustomCallback()],
                    verbose=1)
# Out:
# Training: begins at Tue, 12 Jul 2022 16:05:21
# Epoch 1/5
# 77/77 [==============================] - 2s 8ms/step - loss: 0.4616 - binary_accuracy: 0.7940 - val_loss: 0.4257 - val_binary_accuracy: 0.7962
# Epoch 2/5
# 77/77 [==============================] - 0s 6ms/step - loss: 0.4323 - binary_accuracy: 0.8083 - val_loss: 0.4308 - val_binary_accuracy: 0.8262
# Epoch 3/5
# 77/77 [==============================] - 0s 4ms/step - loss: 0.4349 - binary_accuracy: 0.8254 - val_loss: 0.4151 - val_binary_accuracy: 0.8295
# Epoch 4/5
# 77/77 [==============================] - 0s 4ms/step - loss: 0.4276 - binary_accuracy: 0.8254 - val_loss: 0.4130 - val_binary_accuracy: 0.8300
# Epoch 5/5
# 77/77 [==============================] - 0s 6ms/step - loss: 0.4205 - binary_accuracy: 0.8271 - val_loss: 0.3949 - val_binary_accuracy: 0.8371
# Training: ends at Tue, 12 Jul 2022 16:05:25
# Duration: 3.13 seconds

# %%
loss, acc = model.evaluate(x=x_train,y=y_train, batch_size=32)
print('Train loss: %.4f - acc: %.4f' % (loss, acc))

loss_, acc_ = model.evaluate(x=x_val,y=y_val, batch_size=32)
print('Test loss: %.4f - acc: %.4f' % (loss_, acc_))
# Out:
# 154/154 [==============================] - 0s 1ms/step - loss: 0.4015 - binary_accuracy: 0.8328
# Train loss: 0.4015 - acc: 0.8328
# 66/66 [==============================] - 0s 1ms/step - loss: 0.3949 - binary_accuracy: 0.8371
# Test loss: 0.3949 - acc: 0.8371

# %%
predict = model.predict(x_val)

# %%
predict
# Out:
# array([[0.06163195],
#        [0.07241371],
#        [0.33485508],
#        ...,
#        [0.15238258],
#        [0.3548177 ],
#        [0.08758289]], dtype=float32)

# %% [markdown]
# --------------------------

# %% [markdown]
# ### 4.4.Hyperparameter Tuning

# %% [markdown]
# #### 4.4.1 Monitoring a neural network

# %%
from tensorflow import keras
from wandb.keras import WandbCallback
from keras.callbacks import EarlyStopping

# %%
# Default values for hyperparameters
defaults = dict(layer_1 = 13,
                layer_2 = 12,
                learn_rate = 0.02218,
                batch_size = 64,
                epoch = 10)

wandb.init(project=project_name, config= defaults, name="run_01")
config = wandb.config

# %%
# Instantiate a simple classification model
model = tf.keras.Sequential([
  tf.keras.layers.Dense(config.layer_1, activation=tf.nn.relu),
  tf.keras.layers.Dense(config.layer_2, activation=tf.nn.relu),
  tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

# Instantiate a logistic loss function that expects integer targets.
loss = tf.keras.losses.BinaryCrossentropy()

# Instantiate an accuracy metric.
accuracy = tf.keras.metrics.BinaryAccuracy()

# Instantiate an optimizer.
optimizer = tf.keras.optimizers.SGD(learning_rate=config.learn_rate)

# configure the optimizer, loss, and metrics to monitor.
model.compile(optimizer=optimizer, loss=loss, metrics=[accuracy])

# %%
# %%wandb
# # Add WandbCallback() to the fit function
# model.fit(x=x_train,
#           y=y_train,
#           batch_size=config.batch_size,
#           epochs=config.epoch,
#           validation_data=(x_val,y_val),
#           callbacks=[WandbCallback(log_weights=True)],
#           verbose=0)

# %% [markdown]
# ### 4.4.2 Sweeps

# %%
# The sweep calls this function with each set of hyperparameters
def train():
    # Default values for hyper-parameters we're going to sweep over
    defaults = dict(layer_1 = 13,
                layer_2 = 12,
                learn_rate = 0.02,
                batch_size = 64,
                epoch = 600)
    
    # Initialize a new wandb run
    wandb.init(project=project_name, config= defaults)

    # Config is a variable that holds and saves hyperparameters and inputs
    config = wandb.config
    
    # Instantiate a simple classification model
    model = tf.keras.Sequential([
                                 tf.keras.layers.Dense(config.layer_1, activation=tf.nn.relu, dtype='float64'),
                                 tf.keras.layers.Dense(config.layer_2, activation=tf.nn.relu, dtype='float64'),
                                 tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)
                                 ])

    # Instantiate a logistic loss function that expects integer targets.
    loss = tf.keras.losses.BinaryCrossentropy()

    # Instantiate an accuracy metric.
    accuracy = tf.keras.metrics.BinaryAccuracy()

    # Instantiate an optimizer.
    optimizer = tf.keras.optimizers.SGD(learning_rate=config.learn_rate)

    # configure the optimizer, loss, and metrics to monitor.
    model.compile(optimizer=optimizer, loss=loss, metrics=[accuracy])  

    model.fit(x_train, y_train, batch_size=config.batch_size,
              epochs=config.epoch,
              validation_data=(x_val, y_val),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=100)]
              )

# %%
# Configure the sweep – specify the parameters to search through, the search strategy, the optimization metric et all.
sweep_config = {
    'method': 'random', #grid, random
    'metric': {
      'name': 'binary_accuracy',
      'goal': 'maximize'   
    },
    'parameters': {
        'layer_1': {
            'max': 32,
            'min': 8,
            'distribution': 'int_uniform',
        },
        'layer_2': {
            'max': 32,
            'min': 8,
            'distribution': 'int_uniform',
        },
        'learn_rate': {
            'min': -4,
            'max': -2,
            'distribution': 'log_uniform',  
        },
        'epoch': {
            'values': [300,400,600]
        },
        'batch_size': {
            'values': [32,64]
        }
    }
}

# %%
# Initialize a new sweep
# Arguments:
#     – sweep_config: the sweep config dictionary defined above
#     – entity: Set the username for the sweep
#     – project: Set the project name for the sweep
sweep_id = wandb.sweep(sweep_config, entity=entity_name, project=project_name)
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Create sweep with ID: 9flfl8wj
# Sweep URL: https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9flfl8wj

# %%
# Initialize a new sweep
# Arguments:
#     – sweep_id: the sweep_id to run - this was returned above by wandb.sweep()
#     – function: function that defines your model architecture and trains it
wandb.agent(sweep_id = sweep_id, function=train,count=20)
# Out:
# wandb: Agent Starting Run: 1u43kk80 with config:
# wandb: 	batch_size: 32
# wandb: 	epoch: 300
# wandb: 	layer_1: 29
# wandb: 	layer_2: 18
# wandb: 	learn_rate: 0.08794759082337072
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.12.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.17<br/>
#                 Syncing run <strong style="color:#cdcd00">genial-sweep-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn</a><br/>
#                 Sweep page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9flfl8wj" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9flfl8wj</a><br/>
# Run page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1u43kk80" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1u43kk80</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20220712_183002-1u43kk80</code><br/><br/>
# Epoch 1/300
# 154/154 [==============================] - 1s 4ms/step - loss: 0.4824 - binary_accuracy: 0.7938 - val_loss: 0.4292 - val_binary_accuracy: 0.8033
# Epoch 2/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.4232 - binary_accuracy: 0.8163 - val_loss: 0.3998 - val_binary_accuracy: 0.8190
# Epoch 3/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3945 - binary_accuracy: 0.8279 - val_loss: 0.3825 - val_binary_accuracy: 0.8333
# Epoch 4/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3748 - binary_accuracy: 0.8385 - val_loss: 0.3611 - val_binary_accuracy: 0.8510
# Epoch 5/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3639 - binary_accuracy: 0.8477 - val_loss: 0.3546 - val_binary_accuracy: 0.8586
# Epoch 6/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3584 - binary_accuracy: 0.8516 - val_loss: 0.3514 - val_binary_accuracy: 0.8610
# Epoch 7/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3548 - binary_accuracy: 0.8561 - val_loss: 0.3550 - val_binary_accuracy: 0.8529
# Epoch 8/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3529 - binary_accuracy: 0.8557 - val_loss: 0.3543 - val_binary_accuracy: 0.8519
# Epoch 9/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3502 - binary_accuracy: 0.8550 - val_loss: 0.3501 - val_binary_accuracy: 0.8595
# Epoch 10/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3473 - binary_accuracy: 0.8575 - val_loss: 0.3515 - val_binary_accuracy: 0.8586
# Epoch 11/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3462 - binary_accuracy: 0.8583 - val_loss: 0.3477 - val_binary_accuracy: 0.8581
# Epoch 12/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3449 - binary_accuracy: 0.8581 - val_loss: 0.3451 - val_binary_accuracy: 0.8629
# Epoch 13/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3437 - binary_accuracy: 0.8577 - val_loss: 0.3482 - val_binary_accuracy: 0.8605
# Epoch 14/300
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3416 - binary_accuracy: 0.8597 - val_loss: 0.3436 - val_binary_accuracy: 0.8629
# Epoch 15/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3414 - binary_accuracy: 0.8583 - val_loss: 0.3866 - val_binary_accuracy: 0.8310
# Epoch 16/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3434 - binary_accuracy: 0.8581 - val_loss: 0.3447 - val_binary_accuracy: 0.8624
# Epoch 17/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3383 - binary_accuracy: 0.8597 - val_loss: 0.3484 - val_binary_accuracy: 0.8595
# Epoch 18/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3381 - binary_accuracy: 0.8608 - val_loss: 0.3417 - val_binary_accuracy: 0.8595
# Epoch 19/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3376 - binary_accuracy: 0.8601 - val_loss: 0.3405 - val_binary_accuracy: 0.8648
# Epoch 20/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3364 - binary_accuracy: 0.8606 - val_loss: 0.3420 - val_binary_accuracy: 0.8581
# Epoch 21/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3359 - binary_accuracy: 0.8604 - val_loss: 0.3408 - val_binary_accuracy: 0.8605
# Epoch 22/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3339 - binary_accuracy: 0.8634 - val_loss: 0.3416 - val_binary_accuracy: 0.8619
# Epoch 23/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3333 - binary_accuracy: 0.8630 - val_loss: 0.4056 - val_binary_accuracy: 0.8186
# Epoch 24/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3357 - binary_accuracy: 0.8581 - val_loss: 0.4032 - val_binary_accuracy: 0.8148
# Epoch 25/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3334 - binary_accuracy: 0.8601 - val_loss: 0.3623 - val_binary_accuracy: 0.8448
# Epoch 26/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3337 - binary_accuracy: 0.8614 - val_loss: 0.3510 - val_binary_accuracy: 0.8524
# Epoch 27/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3316 - binary_accuracy: 0.8608 - val_loss: 0.3396 - val_binary_accuracy: 0.8619
# Epoch 28/300
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3302 - binary_accuracy: 0.8632 - val_loss: 0.3434 - val_binary_accuracy: 0.8595
# Epoch 29/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3292 - binary_accuracy: 0.8610 - val_loss: 0.3568 - val_binary_accuracy: 0.8457
# Epoch 30/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3299 - binary_accuracy: 0.8610 - val_loss: 0.4208 - val_binary_accuracy: 0.8243
# Epoch 31/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3313 - binary_accuracy: 0.8636 - val_loss: 0.3397 - val_binary_accuracy: 0.8576
# Epoch 32/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3267 - binary_accuracy: 0.8577 - val_loss: 0.3569 - val_binary_accuracy: 0.8505
# Epoch 33/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3258 - binary_accuracy: 0.8614 - val_loss: 0.3421 - val_binary_accuracy: 0.8586
# Epoch 34/300
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3255 - binary_accuracy: 0.8632 - val_loss: 0.3608 - val_binary_accuracy: 0.8414
# Epoch 35/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3260 - binary_accuracy: 0.8638 - val_loss: 0.3442 - val_binary_accuracy: 0.8610
# Epoch 36/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3241 - binary_accuracy: 0.8632 - val_loss: 0.3428 - val_binary_accuracy: 0.8614
# Epoch 37/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3238 - binary_accuracy: 0.8646 - val_loss: 0.3427 - val_binary_accuracy: 0.8638
# Epoch 38/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3217 - binary_accuracy: 0.8642 - val_loss: 0.3420 - val_binary_accuracy: 0.8624
# Epoch 39/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3210 - binary_accuracy: 0.8624 - val_loss: 0.3424 - val_binary_accuracy: 0.8605
# Epoch 40/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3217 - binary_accuracy: 0.8640 - val_loss: 0.3497 - val_binary_accuracy: 0.8538
# Epoch 41/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3202 - binary_accuracy: 0.8659 - val_loss: 0.3949 - val_binary_accuracy: 0.8200
# Epoch 42/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3214 - binary_accuracy: 0.8677 - val_loss: 0.3419 - val_binary_accuracy: 0.8605
# Epoch 43/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3188 - binary_accuracy: 0.8681 - val_loss: 0.3520 - val_binary_accuracy: 0.8543
# Epoch 44/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3186 - binary_accuracy: 0.8673 - val_loss: 0.3448 - val_binary_accuracy: 0.8581
# Epoch 45/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3182 - binary_accuracy: 0.8667 - val_loss: 0.3489 - val_binary_accuracy: 0.8538
# Epoch 46/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3172 - binary_accuracy: 0.8650 - val_loss: 0.4032 - val_binary_accuracy: 0.8143
# Epoch 47/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3195 - binary_accuracy: 0.8653 - val_loss: 0.3709 - val_binary_accuracy: 0.8400
# Epoch 48/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3151 - binary_accuracy: 0.8675 - val_loss: 0.4165 - val_binary_accuracy: 0.8029
# Epoch 49/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3179 - binary_accuracy: 0.8632 - val_loss: 0.4522 - val_binary_accuracy: 0.7810
# Epoch 50/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3184 - binary_accuracy: 0.8685 - val_loss: 0.3668 - val_binary_accuracy: 0.8548
# Epoch 51/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3172 - binary_accuracy: 0.8673 - val_loss: 0.3453 - val_binary_accuracy: 0.8571
# Epoch 52/300
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3146 - binary_accuracy: 0.8673 - val_loss: 0.3459 - val_binary_accuracy: 0.8557
# Epoch 53/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3136 - binary_accuracy: 0.8659 - val_loss: 0.3466 - val_binary_accuracy: 0.8538
# Epoch 54/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3127 - binary_accuracy: 0.8691 - val_loss: 0.3491 - val_binary_accuracy: 0.8600
# Epoch 55/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3120 - binary_accuracy: 0.8695 - val_loss: 0.3867 - val_binary_accuracy: 0.8286
# Epoch 56/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3116 - binary_accuracy: 0.8689 - val_loss: 0.3882 - val_binary_accuracy: 0.8519
# Epoch 57/300
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3116 - binary_accuracy: 0.8732 - val_loss: 0.3542 - val_binary_accuracy: 0.8548
# Epoch 58/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3108 - binary_accuracy: 0.8681 - val_loss: 0.4323 - val_binary_accuracy: 0.7967
# Epoch 59/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3123 - binary_accuracy: 0.8697 - val_loss: 0.3518 - val_binary_accuracy: 0.8567
# Epoch 60/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3097 - binary_accuracy: 0.8704 - val_loss: 0.4725 - val_binary_accuracy: 0.7976
# Epoch 61/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3101 - binary_accuracy: 0.8693 - val_loss: 0.3559 - val_binary_accuracy: 0.8571
# Epoch 62/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3086 - binary_accuracy: 0.8665 - val_loss: 0.3543 - val_binary_accuracy: 0.8590
# Epoch 63/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3081 - binary_accuracy: 0.8706 - val_loss: 0.3521 - val_binary_accuracy: 0.8605
# Epoch 64/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3064 - binary_accuracy: 0.8683 - val_loss: 0.3571 - val_binary_accuracy: 0.8543
# Epoch 65/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3074 - binary_accuracy: 0.8695 - val_loss: 0.3531 - val_binary_accuracy: 0.8595
# Epoch 66/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3035 - binary_accuracy: 0.8708 - val_loss: 0.3554 - val_binary_accuracy: 0.8519
# Epoch 67/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3067 - binary_accuracy: 0.8722 - val_loss: 0.3553 - val_binary_accuracy: 0.8567
# Epoch 68/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3047 - binary_accuracy: 0.8728 - val_loss: 0.3638 - val_binary_accuracy: 0.8552
# Epoch 69/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3049 - binary_accuracy: 0.8742 - val_loss: 0.4497 - val_binary_accuracy: 0.7867
# Epoch 70/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3053 - binary_accuracy: 0.8716 - val_loss: 0.3544 - val_binary_accuracy: 0.8538
# Epoch 71/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3015 - binary_accuracy: 0.8746 - val_loss: 0.3548 - val_binary_accuracy: 0.8548
# Epoch 72/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3014 - binary_accuracy: 0.8702 - val_loss: 0.4022 - val_binary_accuracy: 0.8452
# Epoch 73/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3037 - binary_accuracy: 0.8724 - val_loss: 0.3588 - val_binary_accuracy: 0.8576
# Epoch 74/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3019 - binary_accuracy: 0.8742 - val_loss: 0.5997 - val_binary_accuracy: 0.7462
# Epoch 75/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3111 - binary_accuracy: 0.8648 - val_loss: 0.3699 - val_binary_accuracy: 0.8548
# Epoch 76/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3016 - binary_accuracy: 0.8732 - val_loss: 0.3590 - val_binary_accuracy: 0.8495
# Epoch 77/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2994 - binary_accuracy: 0.8742 - val_loss: 0.3556 - val_binary_accuracy: 0.8524
# Epoch 78/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3001 - binary_accuracy: 0.8744 - val_loss: 0.3571 - val_binary_accuracy: 0.8576
# Epoch 79/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2991 - binary_accuracy: 0.8720 - val_loss: 0.5871 - val_binary_accuracy: 0.7338
# Epoch 80/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3052 - binary_accuracy: 0.8714 - val_loss: 0.4145 - val_binary_accuracy: 0.8162
# Epoch 81/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2996 - binary_accuracy: 0.8714 - val_loss: 0.3599 - val_binary_accuracy: 0.8543
# Epoch 82/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2957 - binary_accuracy: 0.8759 - val_loss: 0.3700 - val_binary_accuracy: 0.8548
# Epoch 83/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2953 - binary_accuracy: 0.8744 - val_loss: 0.3715 - val_binary_accuracy: 0.8500
# Epoch 84/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2984 - binary_accuracy: 0.8738 - val_loss: 0.3631 - val_binary_accuracy: 0.8533
# Epoch 85/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2947 - binary_accuracy: 0.8791 - val_loss: 0.3601 - val_binary_accuracy: 0.8510
# Epoch 86/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2927 - binary_accuracy: 0.8753 - val_loss: 0.4854 - val_binary_accuracy: 0.8395
# Epoch 87/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2994 - binary_accuracy: 0.8726 - val_loss: 0.3625 - val_binary_accuracy: 0.8548
# Epoch 88/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2938 - binary_accuracy: 0.8785 - val_loss: 0.4517 - val_binary_accuracy: 0.8048
# Epoch 89/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2969 - binary_accuracy: 0.8763 - val_loss: 0.3804 - val_binary_accuracy: 0.8552
# Epoch 90/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2920 - binary_accuracy: 0.8767 - val_loss: 0.3695 - val_binary_accuracy: 0.8500
# Epoch 91/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2908 - binary_accuracy: 0.8769 - val_loss: 0.3656 - val_binary_accuracy: 0.8448
# Epoch 92/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2888 - binary_accuracy: 0.8757 - val_loss: 0.4470 - val_binary_accuracy: 0.7900
# Epoch 93/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2908 - binary_accuracy: 0.8781 - val_loss: 0.3678 - val_binary_accuracy: 0.8429
# Epoch 94/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2892 - binary_accuracy: 0.8797 - val_loss: 0.3858 - val_binary_accuracy: 0.8357
# Epoch 95/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2895 - binary_accuracy: 0.8787 - val_loss: 0.7529 - val_binary_accuracy: 0.6576
# Epoch 96/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2945 - binary_accuracy: 0.8787 - val_loss: 0.3707 - val_binary_accuracy: 0.8500
# Epoch 97/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2864 - binary_accuracy: 0.8810 - val_loss: 0.3692 - val_binary_accuracy: 0.8448
# Epoch 98/300
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2876 - binary_accuracy: 0.8804 - val_loss: 0.3754 - val_binary_accuracy: 0.8400
# Epoch 99/300
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2868 - binary_accuracy: 0.8767 - val_loss: 0.3795 - val_binary_accuracy: 0.8538
# Epoch 100/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2850 - binary_accuracy: 0.8822 - val_loss: 0.3876 - val_binary_accuracy: 0.8510
# Epoch 101/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2871 - binary_accuracy: 0.8802 - val_loss: 0.3836 - val_binary_accuracy: 0.8348
# Epoch 102/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2827 - binary_accuracy: 0.8804 - val_loss: 0.3908 - val_binary_accuracy: 0.8486
# Epoch 103/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2848 - binary_accuracy: 0.8810 - val_loss: 0.3736 - val_binary_accuracy: 0.8467
# Epoch 104/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2818 - binary_accuracy: 0.8808 - val_loss: 0.3782 - val_binary_accuracy: 0.8500
# Epoch 105/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2849 - binary_accuracy: 0.8775 - val_loss: 0.5163 - val_binary_accuracy: 0.8371
# Epoch 106/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2898 - binary_accuracy: 0.8828 - val_loss: 0.3741 - val_binary_accuracy: 0.8471
# Epoch 107/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2834 - binary_accuracy: 0.8820 - val_loss: 0.4304 - val_binary_accuracy: 0.8229
# Epoch 108/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2871 - binary_accuracy: 0.8779 - val_loss: 0.4101 - val_binary_accuracy: 0.8200
# Epoch 109/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2805 - binary_accuracy: 0.8797 - val_loss: 0.3851 - val_binary_accuracy: 0.8486
# Epoch 110/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2826 - binary_accuracy: 0.8816 - val_loss: 0.3830 - val_binary_accuracy: 0.8510
# Epoch 111/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2820 - binary_accuracy: 0.8840 - val_loss: 0.3840 - val_binary_accuracy: 0.8414
# Epoch 112/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2785 - binary_accuracy: 0.8867 - val_loss: 0.5811 - val_binary_accuracy: 0.7310
# Epoch 113/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2876 - binary_accuracy: 0.8738 - val_loss: 0.4692 - val_binary_accuracy: 0.7924
# Epoch 114/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2854 - binary_accuracy: 0.8783 - val_loss: 0.3809 - val_binary_accuracy: 0.8452
# Epoch 115/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2799 - binary_accuracy: 0.8814 - val_loss: 0.3917 - val_binary_accuracy: 0.8524
# Epoch 116/300
# 154/154 [==============================] - 1s 3ms/step - loss: 0.2816 - binary_accuracy: 0.8804 - val_loss: 0.4346 - val_binary_accuracy: 0.8505
# Epoch 117/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2788 - binary_accuracy: 0.8822 - val_loss: 0.3902 - val_binary_accuracy: 0.8376
# Epoch 118/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2786 - binary_accuracy: 0.8826 - val_loss: 0.7809 - val_binary_accuracy: 0.6962
# Epoch 119/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2898 - binary_accuracy: 0.8789 - val_loss: 0.3997 - val_binary_accuracy: 0.8471
# Epoch 120/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2806 - binary_accuracy: 0.8836 - val_loss: 0.4031 - val_binary_accuracy: 0.8276
# Epoch 121/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2775 - binary_accuracy: 0.8826 - val_loss: 0.4019 - val_binary_accuracy: 0.8362
# Epoch 122/300
# 154/154 [==============================] - 0s 2ms/step - loss: 0.2783 - binary_accuracy: 0.8842 - val_loss: 0.4128 - val_binary_accuracy: 0.8476
# Epoch 123/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2764 - binary_accuracy: 0.8830 - val_loss: 0.4183 - val_binary_accuracy: 0.8219
# Epoch 124/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2736 - binary_accuracy: 0.8840 - val_loss: 0.3874 - val_binary_accuracy: 0.8486
# Epoch 125/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2744 - binary_accuracy: 0.8851 - val_loss: 0.9552 - val_binary_accuracy: 0.7376
# Epoch 126/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2971 - binary_accuracy: 0.8767 - val_loss: 0.7955 - val_binary_accuracy: 0.6838
# Epoch 127/300
# 154/154 [==============================] - 0s 3ms/step - loss: 0.2807 - binary_accuracy: 0.8816 - val_loss: 0.4126 - val_binary_accuracy: 0.8476
# <br/>Waiting for W&B process to finish, PID 26162<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20220712_183002-1u43kk80/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20220712_183002-1u43kk80/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>126</td></tr><tr><td>loss</td><td>0.28073</td></tr><tr><td>binary_accuracy</td><td>0.88158</td></tr><tr><td>val_loss</td><td>0.41259</td></tr><tr><td>val_binary_accuracy</td><td>0.84762</td></tr><tr><td>_step</td><td>126</td></tr><tr><td>_runtime</td><td>65</td></tr><tr><td>_timestamp</td><td>1657650667</td></tr><tr><td>best_val_loss</td><td>0.33955</td></tr><tr><td>best_epoch</td><td>26</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>binary_accuracy</td><td>▁▄▆▆▆▆▆▆▆▆▆▆▆▇▇▆▇▇▇▇▇▇▇▇▇▇██▇███████████</td></tr><tr><td>val_loss</td><td>▇▂▂▂▁▁▁▅▂▆▁▁▁▂▅█▁▄▂▂▂▂▅▃▂▂▂█▂▄▃▄▃▇▄▃▄▅▆▅</td></tr><tr><td>val_binary_accuracy</td><td>▃▇▇████▄▇▅███▇▄▁█▅███▇▇▇█▇▇▃▇▆▇▆▇▅▇▇▆▅▅▇</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">genial-sweep-2</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1u43kk80" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/1u43kk80</a><br/>
# wandb: Agent Starting Run: wvx0irnc with config:
# wandb: 	batch_size: 32
# wandb: 	epoch: 600
# wandb: 	layer_1: 19
# wandb: 	layer_2: 27
# wandb: 	learn_rate: 0.0494194796654794
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.12.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.17<br/>
#                 Syncing run <strong style="color:#cdcd00">ethereal-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn</a><br/>
#                 Sweep page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9flfl8wj" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9flfl8wj</a><br/>
# Run page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/wvx0irnc" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/wvx0irnc</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20220712_183112-wvx0irnc</code><br/><br/>
# Epoch 1/600
# 154/154 [==============================] - 1s 4ms/step - loss: 0.5112 - binary_accuracy: 0.7683 - val_loss: 0.4645 - val_binary_accuracy: 0.7962
# Epoch 2/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.4490 - binary_accuracy: 0.8044 - val_loss: 0.4391 - val_binary_accuracy: 0.8105
# Epoch 3/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.4298 - binary_accuracy: 0.8136 - val_loss: 0.4224 - val_binary_accuracy: 0.8219
# Epoch 4/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.4154 - binary_accuracy: 0.8267 - val_loss: 0.4072 - val_binary_accuracy: 0.8310
# Epoch 5/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.4007 - binary_accuracy: 0.8356 - val_loss: 0.3915 - val_binary_accuracy: 0.8381
# Epoch 6/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3876 - binary_accuracy: 0.8428 - val_loss: 0.3846 - val_binary_accuracy: 0.8400
# Epoch 7/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3754 - binary_accuracy: 0.8501 - val_loss: 0.3634 - val_binary_accuracy: 0.8533
# Epoch 8/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3653 - binary_accuracy: 0.8510 - val_loss: 0.3554 - val_binary_accuracy: 0.8567
# Epoch 9/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3596 - binary_accuracy: 0.8534 - val_loss: 0.3559 - val_binary_accuracy: 0.8519
# Epoch 10/600
# 154/154 [==============================] - 1s 4ms/step - loss: 0.3553 - binary_accuracy: 0.8538 - val_loss: 0.3495 - val_binary_accuracy: 0.8571
# Epoch 11/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3525 - binary_accuracy: 0.8542 - val_loss: 0.3524 - val_binary_accuracy: 0.8519
# Epoch 12/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3502 - binary_accuracy: 0.8555 - val_loss: 0.3460 - val_binary_accuracy: 0.8590
# Epoch 13/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3495 - binary_accuracy: 0.8563 - val_loss: 0.3442 - val_binary_accuracy: 0.8600
# Epoch 14/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3469 - binary_accuracy: 0.8559 - val_loss: 0.3608 - val_binary_accuracy: 0.8471
# Epoch 15/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3470 - binary_accuracy: 0.8573 - val_loss: 0.3518 - val_binary_accuracy: 0.8548
# Epoch 16/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3449 - binary_accuracy: 0.8565 - val_loss: 0.3478 - val_binary_accuracy: 0.8505
# Epoch 17/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3440 - binary_accuracy: 0.8577 - val_loss: 0.3426 - val_binary_accuracy: 0.8633
# Epoch 18/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3426 - binary_accuracy: 0.8589 - val_loss: 0.3456 - val_binary_accuracy: 0.8619
# Epoch 19/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3422 - binary_accuracy: 0.8581 - val_loss: 0.3438 - val_binary_accuracy: 0.8600
# Epoch 20/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3410 - binary_accuracy: 0.8567 - val_loss: 0.3492 - val_binary_accuracy: 0.8533
# Epoch 21/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3403 - binary_accuracy: 0.8567 - val_loss: 0.3484 - val_binary_accuracy: 0.8571
# Epoch 22/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3398 - binary_accuracy: 0.8606 - val_loss: 0.3432 - val_binary_accuracy: 0.8595
# Epoch 23/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3387 - binary_accuracy: 0.8581 - val_loss: 0.3434 - val_binary_accuracy: 0.8605
# Epoch 24/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3373 - binary_accuracy: 0.8601 - val_loss: 0.3937 - val_binary_accuracy: 0.8319
# Epoch 25/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3390 - binary_accuracy: 0.8595 - val_loss: 0.3435 - val_binary_accuracy: 0.8619
# Epoch 26/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3373 - binary_accuracy: 0.8591 - val_loss: 0.3671 - val_binary_accuracy: 0.8400
# Epoch 27/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3364 - binary_accuracy: 0.8577 - val_loss: 0.3459 - val_binary_accuracy: 0.8638
# Epoch 28/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3351 - binary_accuracy: 0.8587 - val_loss: 0.3493 - val_binary_accuracy: 0.8614
# Epoch 29/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3344 - binary_accuracy: 0.8595 - val_loss: 0.3419 - val_binary_accuracy: 0.8614
# Epoch 30/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3341 - binary_accuracy: 0.8591 - val_loss: 0.3552 - val_binary_accuracy: 0.8548
# Epoch 31/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3339 - binary_accuracy: 0.8579 - val_loss: 0.3419 - val_binary_accuracy: 0.8590
# Epoch 32/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3320 - binary_accuracy: 0.8601 - val_loss: 0.3466 - val_binary_accuracy: 0.8581
# Epoch 33/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3320 - binary_accuracy: 0.8577 - val_loss: 0.3430 - val_binary_accuracy: 0.8595
# Epoch 34/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3312 - binary_accuracy: 0.8606 - val_loss: 0.3629 - val_binary_accuracy: 0.8571
# Epoch 35/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3328 - binary_accuracy: 0.8595 - val_loss: 0.3448 - val_binary_accuracy: 0.8605
# Epoch 36/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3314 - binary_accuracy: 0.8604 - val_loss: 0.3428 - val_binary_accuracy: 0.8624
# Epoch 37/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3303 - binary_accuracy: 0.8610 - val_loss: 0.3424 - val_binary_accuracy: 0.8638
# Epoch 38/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3292 - binary_accuracy: 0.8591 - val_loss: 0.3429 - val_binary_accuracy: 0.8629
# Epoch 39/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3290 - binary_accuracy: 0.8624 - val_loss: 0.3427 - val_binary_accuracy: 0.8624
# Epoch 40/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3284 - binary_accuracy: 0.8618 - val_loss: 0.3455 - val_binary_accuracy: 0.8619
# Epoch 41/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3278 - binary_accuracy: 0.8618 - val_loss: 0.3494 - val_binary_accuracy: 0.8590
# Epoch 42/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3279 - binary_accuracy: 0.8624 - val_loss: 0.3522 - val_binary_accuracy: 0.8552
# Epoch 43/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3277 - binary_accuracy: 0.8644 - val_loss: 0.3461 - val_binary_accuracy: 0.8629
# Epoch 44/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3273 - binary_accuracy: 0.8616 - val_loss: 0.3458 - val_binary_accuracy: 0.8629
# Epoch 45/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3271 - binary_accuracy: 0.8624 - val_loss: 0.3453 - val_binary_accuracy: 0.8629
# Epoch 46/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3266 - binary_accuracy: 0.8634 - val_loss: 0.3926 - val_binary_accuracy: 0.8286
# Epoch 47/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3274 - binary_accuracy: 0.8620 - val_loss: 0.3537 - val_binary_accuracy: 0.8571
# Epoch 48/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3256 - binary_accuracy: 0.8634 - val_loss: 0.3500 - val_binary_accuracy: 0.8576
# Epoch 49/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3238 - binary_accuracy: 0.8632 - val_loss: 0.3476 - val_binary_accuracy: 0.8595
# Epoch 50/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3242 - binary_accuracy: 0.8640 - val_loss: 0.3557 - val_binary_accuracy: 0.8614
# Epoch 51/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3250 - binary_accuracy: 0.8628 - val_loss: 0.3483 - val_binary_accuracy: 0.8638
# Epoch 52/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3250 - binary_accuracy: 0.8638 - val_loss: 0.3472 - val_binary_accuracy: 0.8624
# Epoch 53/600
# 154/154 [==============================] - 1s 5ms/step - loss: 0.3225 - binary_accuracy: 0.8640 - val_loss: 0.3496 - val_binary_accuracy: 0.8624
# Epoch 54/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3237 - binary_accuracy: 0.8638 - val_loss: 0.3750 - val_binary_accuracy: 0.8490
# Epoch 55/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3256 - binary_accuracy: 0.8591 - val_loss: 0.3588 - val_binary_accuracy: 0.8529
# Epoch 56/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3250 - binary_accuracy: 0.8608 - val_loss: 0.3636 - val_binary_accuracy: 0.8571
# Epoch 57/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3235 - binary_accuracy: 0.8604 - val_loss: 0.3629 - val_binary_accuracy: 0.8552
# Epoch 58/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3220 - binary_accuracy: 0.8640 - val_loss: 0.3494 - val_binary_accuracy: 0.8624
# Epoch 59/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3208 - binary_accuracy: 0.8638 - val_loss: 0.3690 - val_binary_accuracy: 0.8538
# Epoch 60/600
# 154/154 [==============================] - 1s 5ms/step - loss: 0.3225 - binary_accuracy: 0.8626 - val_loss: 0.3535 - val_binary_accuracy: 0.8610
# Epoch 61/600
# 154/154 [==============================] - 1s 7ms/step - loss: 0.3213 - binary_accuracy: 0.8626 - val_loss: 0.3921 - val_binary_accuracy: 0.8333
# Epoch 62/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3211 - binary_accuracy: 0.8659 - val_loss: 0.3615 - val_binary_accuracy: 0.8505
# Epoch 63/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3209 - binary_accuracy: 0.8608 - val_loss: 0.3549 - val_binary_accuracy: 0.8567
# Epoch 64/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3203 - binary_accuracy: 0.8616 - val_loss: 0.3643 - val_binary_accuracy: 0.8471
# Epoch 65/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3188 - binary_accuracy: 0.8673 - val_loss: 0.3773 - val_binary_accuracy: 0.8424
# Epoch 66/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3202 - binary_accuracy: 0.8671 - val_loss: 0.3596 - val_binary_accuracy: 0.8571
# Epoch 67/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3197 - binary_accuracy: 0.8624 - val_loss: 0.3526 - val_binary_accuracy: 0.8562
# Epoch 68/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3173 - binary_accuracy: 0.8671 - val_loss: 0.3547 - val_binary_accuracy: 0.8619
# Epoch 69/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3178 - binary_accuracy: 0.8655 - val_loss: 0.3621 - val_binary_accuracy: 0.8571
# Epoch 70/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3172 - binary_accuracy: 0.8661 - val_loss: 0.3581 - val_binary_accuracy: 0.8629
# Epoch 71/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3176 - binary_accuracy: 0.8632 - val_loss: 0.3543 - val_binary_accuracy: 0.8624
# Epoch 72/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3166 - binary_accuracy: 0.8657 - val_loss: 0.3776 - val_binary_accuracy: 0.8419
# Epoch 73/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3181 - binary_accuracy: 0.8646 - val_loss: 0.3526 - val_binary_accuracy: 0.8624
# Epoch 74/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3179 - binary_accuracy: 0.8640 - val_loss: 0.3562 - val_binary_accuracy: 0.8605
# Epoch 75/600
# 154/154 [==============================] - 1s 4ms/step - loss: 0.3174 - binary_accuracy: 0.8642 - val_loss: 0.3554 - val_binary_accuracy: 0.8576
# Epoch 76/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3155 - binary_accuracy: 0.8659 - val_loss: 0.3566 - val_binary_accuracy: 0.8595
# Epoch 77/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3164 - binary_accuracy: 0.8655 - val_loss: 0.3638 - val_binary_accuracy: 0.8548
# Epoch 78/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3155 - binary_accuracy: 0.8644 - val_loss: 0.4855 - val_binary_accuracy: 0.7710
# Epoch 79/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3186 - binary_accuracy: 0.8669 - val_loss: 0.3608 - val_binary_accuracy: 0.8548
# Epoch 80/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3160 - binary_accuracy: 0.8669 - val_loss: 0.3558 - val_binary_accuracy: 0.8610
# Epoch 81/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3141 - binary_accuracy: 0.8644 - val_loss: 0.3676 - val_binary_accuracy: 0.8510
# Epoch 82/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3138 - binary_accuracy: 0.8673 - val_loss: 0.3574 - val_binary_accuracy: 0.8567
# Epoch 83/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3140 - binary_accuracy: 0.8677 - val_loss: 0.3658 - val_binary_accuracy: 0.8581
# Epoch 84/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3146 - binary_accuracy: 0.8634 - val_loss: 0.3585 - val_binary_accuracy: 0.8600
# Epoch 85/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3131 - binary_accuracy: 0.8661 - val_loss: 0.3586 - val_binary_accuracy: 0.8590
# Epoch 86/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3140 - binary_accuracy: 0.8644 - val_loss: 0.3562 - val_binary_accuracy: 0.8600
# Epoch 87/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3118 - binary_accuracy: 0.8679 - val_loss: 0.3576 - val_binary_accuracy: 0.8605
# Epoch 88/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3119 - binary_accuracy: 0.8659 - val_loss: 0.3559 - val_binary_accuracy: 0.8557
# Epoch 89/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3128 - binary_accuracy: 0.8644 - val_loss: 0.4059 - val_binary_accuracy: 0.8186
# Epoch 90/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3133 - binary_accuracy: 0.8675 - val_loss: 0.4228 - val_binary_accuracy: 0.8457
# Epoch 91/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3157 - binary_accuracy: 0.8675 - val_loss: 0.3629 - val_binary_accuracy: 0.8605
# Epoch 92/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3124 - binary_accuracy: 0.8669 - val_loss: 0.3611 - val_binary_accuracy: 0.8581
# Epoch 93/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3110 - binary_accuracy: 0.8648 - val_loss: 0.4097 - val_binary_accuracy: 0.8176
# Epoch 94/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3113 - binary_accuracy: 0.8657 - val_loss: 0.3587 - val_binary_accuracy: 0.8562
# Epoch 95/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3108 - binary_accuracy: 0.8659 - val_loss: 0.3718 - val_binary_accuracy: 0.8586
# Epoch 96/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3113 - binary_accuracy: 0.8677 - val_loss: 0.3669 - val_binary_accuracy: 0.8576
# Epoch 97/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3099 - binary_accuracy: 0.8697 - val_loss: 0.3612 - val_binary_accuracy: 0.8605
# Epoch 98/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3101 - binary_accuracy: 0.8683 - val_loss: 0.3777 - val_binary_accuracy: 0.8600
# Epoch 99/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3107 - binary_accuracy: 0.8693 - val_loss: 0.3602 - val_binary_accuracy: 0.8571
# Epoch 100/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3103 - binary_accuracy: 0.8646 - val_loss: 0.3712 - val_binary_accuracy: 0.8533
# Epoch 101/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3097 - binary_accuracy: 0.8661 - val_loss: 0.3677 - val_binary_accuracy: 0.8567
# Epoch 102/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3093 - binary_accuracy: 0.8702 - val_loss: 0.3721 - val_binary_accuracy: 0.8552
# Epoch 103/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3077 - binary_accuracy: 0.8702 - val_loss: 0.3848 - val_binary_accuracy: 0.8448
# Epoch 104/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3090 - binary_accuracy: 0.8665 - val_loss: 0.3838 - val_binary_accuracy: 0.8424
# Epoch 105/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3088 - binary_accuracy: 0.8665 - val_loss: 0.3661 - val_binary_accuracy: 0.8543
# Epoch 106/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3064 - binary_accuracy: 0.8681 - val_loss: 0.3664 - val_binary_accuracy: 0.8576
# Epoch 107/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3079 - binary_accuracy: 0.8665 - val_loss: 0.3631 - val_binary_accuracy: 0.8600
# Epoch 108/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3075 - binary_accuracy: 0.8695 - val_loss: 0.3638 - val_binary_accuracy: 0.8567
# Epoch 109/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3059 - binary_accuracy: 0.8673 - val_loss: 0.3681 - val_binary_accuracy: 0.8538
# Epoch 110/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3050 - binary_accuracy: 0.8683 - val_loss: 0.3638 - val_binary_accuracy: 0.8581
# Epoch 111/600
# 154/154 [==============================] - 1s 4ms/step - loss: 0.3055 - binary_accuracy: 0.8706 - val_loss: 0.3626 - val_binary_accuracy: 0.8590
# Epoch 112/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3043 - binary_accuracy: 0.8673 - val_loss: 0.3751 - val_binary_accuracy: 0.8462
# Epoch 113/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3058 - binary_accuracy: 0.8689 - val_loss: 0.3638 - val_binary_accuracy: 0.8614
# Epoch 114/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3046 - binary_accuracy: 0.8681 - val_loss: 0.3657 - val_binary_accuracy: 0.8619
# Epoch 115/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3050 - binary_accuracy: 0.8691 - val_loss: 0.3882 - val_binary_accuracy: 0.8548
# Epoch 116/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3048 - binary_accuracy: 0.8708 - val_loss: 0.3866 - val_binary_accuracy: 0.8595
# Epoch 117/600
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3034 - binary_accuracy: 0.8699 - val_loss: 0.3651 - val_binary_accuracy: 0.8538
# Epoch 118/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3030 - binary_accuracy: 0.8697 - val_loss: 0.3661 - val_binary_accuracy: 0.8567
# Epoch 119/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3031 - binary_accuracy: 0.8722 - val_loss: 0.4340 - val_binary_accuracy: 0.8062
# Epoch 120/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3054 - binary_accuracy: 0.8708 - val_loss: 0.3706 - val_binary_accuracy: 0.8614
# Epoch 121/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3035 - binary_accuracy: 0.8671 - val_loss: 0.3660 - val_binary_accuracy: 0.8571
# Epoch 122/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3036 - binary_accuracy: 0.8693 - val_loss: 0.3663 - val_binary_accuracy: 0.8605
# Epoch 123/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3032 - binary_accuracy: 0.8720 - val_loss: 0.3805 - val_binary_accuracy: 0.8324
# Epoch 124/600
# 154/154 [==============================] - 1s 3ms/step - loss: 0.3033 - binary_accuracy: 0.8714 - val_loss: 0.3681 - val_binary_accuracy: 0.8557
# Epoch 125/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3010 - binary_accuracy: 0.8695 - val_loss: 0.3763 - val_binary_accuracy: 0.8524
# Epoch 126/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3023 - binary_accuracy: 0.8685 - val_loss: 0.3679 - val_binary_accuracy: 0.8571
# Epoch 127/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3005 - binary_accuracy: 0.8695 - val_loss: 0.4008 - val_binary_accuracy: 0.8205
# Epoch 128/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3010 - binary_accuracy: 0.8681 - val_loss: 0.3721 - val_binary_accuracy: 0.8529
# Epoch 129/600
# 154/154 [==============================] - 0s 3ms/step - loss: 0.3009 - binary_accuracy: 0.8742 - val_loss: 0.3746 - val_binary_accuracy: 0.8519
# <br/>Waiting for W&B process to finish, PID 26860<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20220712_183112-wvx0irnc/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20220712_183112-wvx0irnc/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>128</td></tr><tr><td>loss</td><td>0.30091</td></tr><tr><td>binary_accuracy</td><td>0.87423</td></tr><tr><td>val_loss</td><td>0.37461</td></tr><tr><td>val_binary_accuracy</td><td>0.8519</td></tr><tr><td>_step</td><td>128</td></tr><tr><td>_runtime</td><td>65</td></tr><tr><td>_timestamp</td><td>1657650737</td></tr><tr><td>best_val_loss</td><td>0.34188</td></tr><tr><td>best_epoch</td><td>28</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>binary_accuracy</td><td>▁▃▆▆▆▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇██▇▇▇█▇▇█▇██▇███████</td></tr><tr><td>val_loss</td><td>▆▄▂▁▂▁▁▃▂▂▂▁▁▁▃▂▁▂▂▂▂▂▃▂█▂▂▂▂▂▃▂▃▂▂▂▂▂▂▂</td></tr><tr><td>val_binary_accuracy</td><td>▄▆██▇█▇▆▆▇████▅████▇██▆█▁██▇█▇█▇▆█████▇▇</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ethereal-sweep-3</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/wvx0irnc" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/wvx0irnc</a><br/>

# %%
run.finish()

# %% [markdown]
# ### 4.5 Export the best model

# %%
run = wandb.init(project=project_name,job_type="best_model")
# Out:
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.12.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.17<br/>
#                 Syncing run <strong style="color:#cdcd00">ethereal-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn</a><br/>
#                 Sweep page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9flfl8wj" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9flfl8wj</a><br/>
# Run page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/wvx0irnc" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/wvx0irnc</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20220712_183300-wvx0irnc</code><br/><br/>

# %%
# restore the raw model file "XXXXX" from a specific run "YYYYYY"
best_model = wandb.restore('model-best.h5', run_path="eec1509/churn_prediction_project_nn/1u43kk80")

# %%
# restore the model for tf.keras
model = tf.keras.models.load_model(best_model.name)

# %%
# execute the loss and accuracy using the test dataset
loss_, acc_ = model.evaluate(x=x_val,y=y_val, batch_size=64)
print('Test loss: %.3f - acc: %.3f' % (loss_, acc_))
# Out:
# 33/33 [==============================] - 0s 1ms/step - loss: 0.3396 - binary_accuracy: 0.8619
# Test loss: 0.340 - acc: 0.862

# %%
# source: https://github.com/wandb/awesome-dl-projects/blob/master/ml-tutorial/EMNIST_Dense_Classification.ipynb
import seaborn as sns
from sklearn.metrics import confusion_matrix

predictions = np.greater_equal(model.predict(x_val),0.5).astype(int)
cm = confusion_matrix(y_true = y_val, y_pred = predictions)

plt.figure(figsize=(6,6));
sns.heatmap(cm, annot=True)
plt.savefig('confusion_matrix.png', bbox_inches='tight')
plt.show()

# %%
wandb.log({"image_confusion_matrix": [wandb.Image('confusion_matrix.png')]})

# %%
# types and names of the artifacts
artifact_type = "inference_artifact"
artifact_encoder = "target_encoder"
artifact_model = "model_export"

# %%
logger.info("Dumping the artifacts to disk")
# Save the model using joblib
joblib.dump(model, artifact_model)

# Save the target encoder using joblib
joblib.dump(le, artifact_encoder)
# Out:
# 12-07-2022 18:35:51 Dumping the artifacts to disk
# INFO:tensorflow:Assets written to: ram://9b44ed5d-7791-4543-8437-4293607d4a15/assets
# 12-07-2022 18:35:51 Assets written to: ram://9b44ed5d-7791-4543-8437-4293607d4a15/assets
# ['target_encoder']

# %%
# Model artifact
artifact = wandb.Artifact(artifact_model,
                          type=artifact_type,
                          description="Neural Network Model for Classification Purpose"
                          )

logger.info("Logging model artifact")
artifact.add_file(artifact_model)
run.log_artifact(artifact)
# Out:
# 12-07-2022 18:35:53 Logging model artifact

# %%
# Target encoder artifact
artifact = wandb.Artifact(artifact_encoder,
                          type=artifact_type,
                          description="The encoder used to encode the target variable"
                          )

logger.info("Logging target enconder artifact")
artifact.add_file(artifact_encoder)
run.log_artifact(artifact)
# Out:
# 12-07-2022 18:35:56 Logging target enconder artifact

# %%
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 27572<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.11MB of 0.11MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20220712_183300-wvx0irnc/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20220712_183300-wvx0irnc/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_step</td><td>0</td></tr><tr><td>_runtime</td><td>166</td></tr><tr><td>_timestamp</td><td>1657650946</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_step</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ethereal-sweep-3</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/wvx0irnc" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/wvx0irnc</a><br/>

# %% [markdown]
# ## 5.Testing

# %%
# initiate the wandb project
run = wandb.init(project="churn_prediction_project_nn",job_type="test")
# Out:
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.12.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.17<br/>
#                 Syncing run <strong style="color:#cdcd00">ethereal-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn</a><br/>
#                 Sweep page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9flfl8wj" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/sweeps/9flfl8wj</a><br/>
# Run page: <a href="https://wandb.ai/eec1509/churn_prediction_project_nn/runs/wvx0irnc" target="_blank">https://wandb.ai/eec1509/churn_prediction_project_nn/runs/wvx0irnc</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20220712_183608-wvx0irnc</code><br/><br/>

# %%
# global variables

# name of the artifact related to test dataset
artifact_test_name = "churn_prediction_project_nn/test.csv:latest"

# name of the model artifact
artifact_model_name = "churn_prediction_project_nn/model_export:latest"

# name of the target encoder artifact
artifact_encoder_name = "churn_prediction_project_nn/target_encoder:latest"

# %%
# configure logging
logging.basicConfig(level=logging.INFO,
                    format="%(asctime)s %(message)s",
                    datefmt='%d-%m-%Y %H:%M:%S')

# reference for a logging obj
logger = logging.getLogger()

# %%
logger.info("Downloading and reading test artifact")
test_data_path = run.use_artifact(artifact_test_name).file()
df_test = pd.read_csv(test_data_path)

# Extract the target from the features
logger.info("Extracting target from dataframe")
x_test = df_test.copy()
y_test = x_test.pop("Exited")
# Out:
# 12-07-2022 18:36:19 Downloading and reading test artifact
# 12-07-2022 18:36:20 Extracting target from dataframe

# %%
x_test.head()
# Out:
#    CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0     1.444462 -0.188991  0.342162 -1.223574       0.799493   0.643094
# 1    -1.342163 -0.378131  0.342162  0.322420      -0.912483   0.643094
# 2     0.636444 -0.188991 -1.386929  0.490091       0.799493  -1.554982
# 3     0.812550 -0.094421  1.725435 -1.223574       0.799493   0.643094
# 4     0.460338  1.229557  1.033799  0.428231      -0.912483   0.643094
#
#    IsActiveMember  EstimatedSalary  x0_Germany  x0_Spain  x0_Male
# 0        0.966559         0.348453         0.0       1.0      1.0
# 1       -1.034598        -1.548861         0.0       0.0      1.0
# 2       -1.034598         1.217124         0.0       0.0      0.0
# 3       -1.034598         1.571193         0.0       1.0      0.0
# 4        0.966559        -1.340022         1.0       0.0      1.0

# %%
y_test.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
# Extract the encoding of the target variable
logger.info("Extracting the encoding of the target variable")
encoder_export_path = run.use_artifact(artifact_encoder_name).file()
le = joblib.load(encoder_export_path)
# Out:
# 12-07-2022 18:36:26 Extracting the encoding of the target variable

# %%
y_test
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2995    0
# 2996    0
# 2997    0
# 2998    1
# 2999    0
# Name: Exited, Length: 3000, dtype: int64

# %%
# Download inference artifact
logger.info("Downloading and load the exported model")
model_export_path = run.use_artifact(artifact_model_name).file()
model = joblib.load(model_export_path)
# Out:
# 12-07-2022 18:36:34 Downloading and load the exported model

# %%
# predict
logger.info("Infering")
predict = model.predict(x_test)

# Evaluation Metrics
logger.info("Test Evaluation metrics")
fbeta = fbeta_score(y_test, predict, beta=1, zero_division=1)
precision = precision_score(y_test, predict, zero_division=1)
recall = recall_score(y_test, predict, zero_division=1)
acc = accuracy_score(y_test, predict)

logger.info("Test Accuracy: {}".format(acc))
logger.info("Test Precision: {}".format(precision))
logger.info("Test Recall: {}".format(recall))
logger.info("Test F1: {}".format(fbeta))

run.summary["Acc"] = acc
run.summary["Precision"] = precision
run.summary["Recall"] = recall
run.summary["F1"] = fbeta
# Out:
# 12-07-2022 18:36:39 Infering
# 12-07-2022 18:36:39 Test Evaluation metrics
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-1c035572a546> in <module>()
#       5 # Evaluation Metrics
#       6 logger.info("Test Evaluation metrics")
# ----> 7 fbeta = fbeta_score(y_test, predict, beta=1, zero_division=1)
#       8 precision = precision_score(y_test, predict, zero_division=1)
#       9 recall = recall_score(y_test, predict, zero_division=1)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1268         warn_for=("f-score",),
#    1269         sample_weight=sample_weight,
# -> 1270         zero_division=zero_division,
#    1271     )
#    1272     return f
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1542     if beta < 0:
#    1543         raise ValueError("beta should be >=0 in the F-beta score")
# -> 1544     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1545
#    1546     # Calculate tp_sum, pred_sum, true_sum ###
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1346         raise ValueError("average has to be one of " + str(average_options))
#    1347
# -> 1348     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1349     # Convert to Python primitive type to avoid NumPy type / Python str
#    1350     # comparison. See https://github.com/numpy/numpy/issues/6784
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
# ---> 95                 type_true, type_pred
#      96             )
#      97         )
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %%
predict
# Out:
# array([[0.01399809],
#        [0.14686862],
#        [0.02276677],
#        ...,
#        [0.51512253],
#        [0.28225142],
#        [0.00341931]], dtype=float32)

# %%
# Compare the accuracy, precision, recall with previous ones
print(classification_report(y_test,predict))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-852e5120dbde> in <module>()
#       1 # Compare the accuracy, precision, recall with previous ones
# ----> 2 print(classification_report(y_test,predict))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2108     """
#    2109
# -> 2110     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2111
#    2112     if labels is None:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
# ---> 95                 type_true, type_pred
#      96             )
#      97         )
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %%
fig_confusion_matrix, ax = plt.subplots(1,1,figsize=(7,4))
ConfusionMatrixDisplay(confusion_matrix(predict,y_test,labels=[1,0]),
                       display_labels=["1","0"]).plot(values_format=".0f",ax=ax)

ax.set_xlabel("True Label")
ax.set_ylabel("Predicted Label")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-63d9de5e7d99> in <module>()
#       1 fig_confusion_matrix, ax = plt.subplots(1,1,figsize=(7,4))
# ----> 2 ConfusionMatrixDisplay(confusion_matrix(predict,y_test,labels=[1,0]),
#       3                        display_labels=["1","0"]).plot(values_format=".0f",ax=ax)
#       4
#       5 ax.set_xlabel("True Label")
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
# ---> 95                 type_true, type_pred
#      96             )
#      97         )
#
# ValueError: Classification metrics can't handle a mix of continuous and binary targets

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.79467</td></tr><tr><td>F1</td><td>0.51496</td></tr><tr><td>Precision</td><td>0.49621</td></tr><tr><td>Recall</td><td>0.53519</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">decent-sweep-12</strong>: <a href="https://wandb.ai/eec1509/churn_prediction_project/runs/193ucjlu" target="_blank">https://wandb.ai/eec1509/churn_prediction_project/runs/193ucjlu</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220529_142321-193ucjlu/logs</code>
